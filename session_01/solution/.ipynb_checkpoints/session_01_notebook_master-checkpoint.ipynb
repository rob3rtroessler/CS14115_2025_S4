# %% [markdown]
# <div style='background: #FF7B47; padding: 10px; border: thin solid darblue; border-radius: 5px; margin-bottom: 2vh'>
#
# # Session 01 - Notebook
#
# Like most session notebooks in this course, this notebook is divided into two parts. Part one is a 'manual' that will allow you to code along with the new code that we introduce at the beginning of each session. The second part is the actual lab/assignment part, where you will work through a few practical tasks and write small but useful programs.

# %% [markdown]
# <div style='background: #FF7B47; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Part 1 -  Manual

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.1 - "hello, world!"

# %%
# your code here

print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.2 - basic datatypes - strings and numeric variables

# %%
# your code here

print(2)
print(2+4)
print(2**4)
# Out:
# 2
# 6
# 16

# %%
number = 2
print(number)
# Out:
# 2

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.3 - basic operations

# %%
# your code here
print(number+number)
print(number-number) 
print(number*3)
print(number/2)
print(number**2)
# Out:
# 4
# 0
# 6
# 1.0
# 4

# %%
# comparision operators
print(2==2)
print(1==0)
print(1!=0)

# logical operators
print(True and True)
print(False and True)
print(False or True)
print(not True)
# Out:
# True
# False
# True
# True
# False
# True
# False

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.4 - advanced data types to store collections of data

# %%
# your code here - lists
my_list_numbers = [10,21,33,14,5]
my_list_strings = ['ten', 'twenty', 'dog', 'cat']
my_list_mixed = [10, 'ten', 'dog', 5, 'cat']
my_list_of_lists =[[1,2,3],['dog','cat'], [1,'cat','2']]

print(my_list_numbers[0])
print(my_list_strings[1], my_list_mixed[2])
print(my_list_of_lists[0])
# Out:
# 10
# twenty dog
# [1, 2, 3]

# %%
# your code here - dictionaries


my_dict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964,
    "example" : {'test':'here', 'test_2': 'here_2'}  
}

print(my_dict['brand'])
print(my_dict['example'])
print(my_dict['example']['test'])
# Out:
# Ford
# {'test': 'here', 'test_2': 'here_2'}
# here

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.5 - for loops

# %%
# your code here

for character in "banana":
    print(character)
# Out:
# b
# a
# n
# a
# n
# a

# %%
fruits = ['apple','banana', 'strawberry', "peach"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# strawberry
# peach

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.6 - Python If ... Else

# %%
# your code here

a = 33
b = 33
if b > a:
    print("b is greater than a")
elif a == b:
    print("a and b are equal")
else:
    print("a is greater than b")
# Out:
# a and b are equal

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.6 - Functions

# %%
# Your code here
def say_hello_to(name):
    print("hello, " + name)

# %%
say_hello_to('Nathan')
# Out:
# hello, Nathan

# %% [markdown]
# <div style='background: #6A9EB4; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Part 2 - Lab
#
# During today's lab you will write code that will help the College to perform the house lottery more efficiently and assist the house administrations in a variety of tasks.

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Task #1 - automatize the house lottery
#
# In the precirculated template folder, you will find the file students.csv with all rising sophomores that will enter the house lottery, i.e. they will get assigned to one of the twelve undergraduate houses. So far, the college has done this task manually but they hope that you can help them to automtize that process. Please load the csv and add another column 'house_id'. Pyhton's csv package will come in handy to load the csv file and treat each row as a list. Having loaded the file, add a random house id to each student and save that information in a new csv file. You might find the python package 'random' quite useful to automatize the lottery process. We've imported the package for you and provided an example.

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# Examples and precirculated code:

# %%
# house ids lookup tables

house_to_id = {
    'Adams House': 0,
    'Cabot House': 1,
    'Currier House': 2,
    'Dunster House': 3,
    'Eliot House': 4,
    'Kirkland House': 5,
    'Leverett House': 6,
    'Lowell House': 7,
    'Mather House': 8,
    'Pforzheimer House':9,
    'Quincy House': 10,
    'Winthrop House': 11
}

id_to_house = {
    0: 'Adams House',
    1: 'Cabot House',
    2: 'Currier House',
    3: 'Dunster House',
    4: 'Eliot House',
    5: 'Kirkland House',
    6: 'Leverett House',
    7: 'Lowell House',
    8: 'Mather House',
    9: 'Pforzheimer House',
    10: 'Quincy House',
    11: 'Winthrop House'
}

# %%
# importing useful python packages
import random
import csv

# %%
# some example code snippets on how to load a CSV file and how to write into one

# read
file_read = open("data/students.csv", "r")
reader = csv.reader(file_read)

for row in reader:
    print(row)
    break # breaking after first element feel free to check out the entire data structure
    
file_read.close()

# write - notice that the file doesn't have to exist beforehand! csv write will create the file automatically, which is very useful!
file_write = open('data/students_with_house.csv', 'w', newline='')

writer = csv.writer(file_write)

# we just write one row here. It might be useful to put this line into a loop when automatizing things
writer.writerow(['first_name', 'last_name', 'HUID', 'email', 'house_id'])

file_write.close()
# Out:
# ['Oona', 'Swigart', '16076420', 'Oona.Swigart@college.harvard.edu']

# %%
# set the random seed for reproducibility
random.seed(14115)

# generate a single random value
single_random_value = random.randint(1, 10)
print("Single random value:", single_random_value)

# generate random values within a loop
for i in range(5):
    temp_random_value = random.randint(1, 10)
    print(f"Random value in iteration {i}: {temp_random_value}")
# Out:
# Single random value: 9
# Random value in iteration 0: 5
# Random value in iteration 1: 7
# Random value in iteration 2: 6
# Random value in iteration 3: 7
# Random value in iteration 4: 10

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# Your turn - load the csv file, create a random number for each student between 0-11 and store all students in a new csv file with their respective house assignments. A for loop might come in handy.

# %%
# your code here

# %%
# solution

# reader & writer
file_read = open("data/students.csv", "r")
file_write = open('data/students_with_house.csv', 'w', newline='') # this is a new file!

reader = csv.reader(file_read)
writer = csv.writer(file_write)

# write first row with column names
writer.writerow(['first_name', 'last_name', 'HUID', 'email', 'house_id'])

for student_line in reader: # iterate over each line in the reader file. Each line is a list that represents a student
    student_line.append(random.randint(0,11)) # append random integer to each student
    # print(student_line)
    writer.writerow(student_line)

# close the files
file_read.close()
file_write.close()

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# Write a small program that makes sure that you've successfully created and populated a csv with all students and their assigned houses.

# %%
# your code here
file_test = open('data/students_with_house.csv', 'r')
reader = csv.reader(file_test)
for line in reader:
    print(line)

file_test.close()
# Out:
# ['first_name', 'last_name', 'HUID', 'email', 'house_id']
# ['Oona', 'Swigart', '16076420', 'Oona.Swigart@college.harvard.edu', '3']
# ['Hope', 'Quent', '16435294', 'Hope.Quent@college.harvard.edu', '10']
# ['Fayre', 'Vorster', '11185066', 'Fayre.Vorster@college.harvard.edu', '10']
# ['Priscilla', 'Geffner', '14666772', 'Priscilla.Geffner@college.harvard.edu', '3']
# ['Madeleine', 'Stilwell', '13502774', 'Madeleine.Stilwell@college.harvard.edu', '10']
# ['Deirdre', 'Khorma', '11100518', 'Deirdre.Khorma@college.harvard.edu', '11']
# ['Anthia', 'Blase', '14657089', 'Anthia.Blase@college.harvard.edu', '0']
# ['Diena', 'Shama', '13777228', 'Diena.Shama@college.harvard.edu', '3']
# ['Cristabel', 'Audly', '19191289', 'Cristabel.Audly@college.harvard.edu', '10']
# ['Misha', 'Tybald', '15474105', 'Misha.Tybald@college.harvard.edu', '10']
# ['Carly', 'Haymes', '10825876', 'Carly.Haymes@college.harvard.edu', '4']
# ['Chloris', 'Shaddock', '14456015', 'Chloris.Shaddock@college.harvard.edu', '2']
# ['Evita', 'Whittaker', '16942112', 'Evita.Whittaker@college.harvard.edu', '0']
# ['Fina', 'Zetta', '17941504', 'Fina.Zetta@college.harvard.edu', '11']
# ['Carolina', 'Ummersen', '12399079', 'Carolina.Ummersen@college.harvard.edu', '8']
# ['Roberta', 'Ingra', '11936833', 'Roberta.Ingra@college.harvard.edu', '11']
# ['Moyna', 'Dorothy', '12556187', 'Moyna.Dorothy@college.harvard.edu', '7']
# ['Zondra', 'Cadmar', '12486497', 'Zondra.Cadmar@college.harvard.edu', '1']
# ['Gusty', 'Merat', '11280490', 'Gusty.Merat@college.harvard.edu', '2']
# ['Bertine', 'Merell', '19533403', 'Bertine.Merell@college.harvard.edu', '11']
# ['Pierette', 'Hutchison', '16577108', 'Pierette.Hutchison@college.harvard.edu', '7']
# ['Sue', 'Oneida', '16223298', 'Sue.Oneida@college.harvard.edu', '4']
# ['Gale', 'Hermes', '10553554', 'Gale.Hermes@college.harvard.edu', '7']
# ['Inga', 'Bow', '15657083', 'Inga.Bow@college.harvard.edu', '3']
# ['Jaclyn', 'Flita', '18705071', 'Jaclyn.Flita@college.harvard.edu', '10']
# ['Bernardine', 'Sophronia', '16311101', 'Bernardine.Sophronia@college.harvard.edu', '3']
# ['Chrystel', 'Borrell', '16164885', 'Chrystel.Borrell@college.harvard.edu', '7']
# ['Larine', 'Paton', '14731172', 'Larine.Paton@college.harvard.edu', '7']
# ['Phedra', 'Lia', '11868072', 'Phedra.Lia@college.harvard.edu', '9']
# ['Melanie', 'Merna', '17144995', 'Melanie.Merna@college.harvard.edu', '4']
# ['Emmey', 'Boehike', '19456940', 'Emmey.Boehike@college.harvard.edu', '3']
# ['Alejandra', 'Ehrman', '16185753', 'Alejandra.Ehrman@college.harvard.edu', '1']
# ['Yetty', 'Monaco', '14071918', 'Yetty.Monaco@college.harvard.edu', '5']
# ['Deirdre', 'Ioab', '11777577', 'Deirdre.Ioab@college.harvard.edu', '9']
# ['Catrina', 'Persse', '14686761', 'Catrina.Persse@college.harvard.edu', '3']
# ['Heida', 'Izaak', '13942697', 'Heida.Izaak@college.harvard.edu', '5']
# ['Sharai', 'Meli', '16097823', 'Sharai.Meli@college.harvard.edu', '5']
# ['Aryn', 'Hanleigh', '19408239', 'Aryn.Hanleigh@college.harvard.edu', '7']
# ['Melina', 'Elsinore', '13761016', 'Melina.Elsinore@college.harvard.edu', '5']
# ['Elyssa', 'Wu', '12316153', 'Elyssa.Wu@college.harvard.edu', '3']
# ['Penelopa', 'Harned', '16443115', 'Penelopa.Harned@college.harvard.edu', '1']
# ['Rozele', 'Wilkinson', '15118764', 'Rozele.Wilkinson@college.harvard.edu', '9']
# ['Melina', 'Jethro', '15840321', 'Melina.Jethro@college.harvard.edu', '11']
# ['Jordan', 'Gilmour', '10076614', 'Jordan.Gilmour@college.harvard.edu', '1']
# ['Ethel', 'Hartnett', '11383680', 'Ethel.Hartnett@college.harvard.edu', '6']
# ['Collen', 'Garek', '17585948', 'Collen.Garek@college.harvard.edu', '6']
# ['Jenilee', 'Vastah', '11949445', 'Jenilee.Vastah@college.harvard.edu', '9']
# ['Fredericka', 'Lane', '12958619', 'Fredericka.Lane@college.harvard.edu', '5']
# ['Asia', 'Demitria', '19103295', 'Asia.Demitria@college.harvard.edu', '5']
# ['Ana', 'Scammon', '10701460', 'Ana.Scammon@college.harvard.edu', '11']
# ['Wynne', 'Baylor', '12487005', 'Wynne.Baylor@college.harvard.edu', '1']
# ['Alexine', 'Ackerley', '14493600', 'Alexine.Ackerley@college.harvard.edu', '6']
# ['Fina', 'Himelman', '16919718', 'Fina.Himelman@college.harvard.edu', '5']
# ['Beth', 'Roxanna', '13130130', 'Beth.Roxanna@college.harvard.edu', '8']
# ['Maud', 'Thema', '19209764', 'Maud.Thema@college.harvard.edu', '0']
# ['Myriam', 'Jerold', '11845800', 'Myriam.Jerold@college.harvard.edu', '1']
# ['Kaia', 'Cavan', '19395700', 'Kaia.Cavan@college.harvard.edu', '4']
# ['Mathilda', 'Urania', '19811224', 'Mathilda.Urania@college.harvard.edu', '1']
# ['Merci', 'Louanna', '14261672', 'Merci.Louanna@college.harvard.edu', '9']
# ['Marti', 'Alva', '15373184', 'Marti.Alva@college.harvard.edu', '9']
# ['Keelia', 'Ricki', '11961947', 'Keelia.Ricki@college.harvard.edu', '2']
# ['Lauryn', 'Tamsky', '14140421', 'Lauryn.Tamsky@college.harvard.edu', '7']
# ['Fidelia', 'Cherianne', '14073512', 'Fidelia.Cherianne@college.harvard.edu', '8']
# ['Emylee', 'Emmaline', '17140291', 'Emylee.Emmaline@college.harvard.edu', '8']
# ['Eve', 'Guthrie', '14490284', 'Eve.Guthrie@college.harvard.edu', '5']
# ['Carmencita', 'Drisko', '17368711', 'Carmencita.Drisko@college.harvard.edu', '2']
# ['Nanete', 'Kenwood', '13603325', 'Nanete.Kenwood@college.harvard.edu', '11']
# ['Maridel', 'Madaih', '10107444', 'Maridel.Madaih@college.harvard.edu', '2']
# ['Gerianna', 'Maples', '11245424', 'Gerianna.Maples@college.harvard.edu', '7']
# ['Mariele', 'Sawtelle', '17643066', 'Mariele.Sawtelle@college.harvard.edu', '1']
# ['Winny', 'Markman', '12461674', 'Winny.Markman@college.harvard.edu', '4']
# ['Isa', 'Suanne', '10263083', 'Isa.Suanne@college.harvard.edu', '3']
# ['Barbara', 'Love', '13075253', 'Barbara.Love@college.harvard.edu', '1']
# ['Ronna', 'Loring', '12850713', 'Ronna.Loring@college.harvard.edu', '6']
# ['Jeanna', 'Isidore', '16935372', 'Jeanna.Isidore@college.harvard.edu', '5']
# ['Kary', 'Kamaria', '18903342', 'Kary.Kamaria@college.harvard.edu', '4']
# ['Ann-Marie', 'Sherrie', '13813311', 'Ann-Marie.Sherrie@college.harvard.edu', '8']
# ['Lolita', 'Harday', '18802346', 'Lolita.Harday@college.harvard.edu', '4']
# ['Dorene', 'Jalbert', '17402190', 'Dorene.Jalbert@college.harvard.edu', '9']
# ['Lanae', 'Nore', '12433872', 'Lanae.Nore@college.harvard.edu', '0']
# ['Mureil', 'McLaughlin', '16406290', 'Mureil.McLaughlin@college.harvard.edu', '2']
# ['Barbi', 'Fabiola', '17888309', 'Barbi.Fabiola@college.harvard.edu', '10']
# ['Valera', 'Pandolfi', '15509054', 'Valera.Pandolfi@college.harvard.edu', '1']
# ['Jennica', 'Kiersten', '15651397', 'Jennica.Kiersten@college.harvard.edu', '5']
# ['Cyb', 'Rurik', '10785022', 'Cyb.Rurik@college.harvard.edu', '0']
# ['Celestyna', 'Annice', '16236203', 'Celestyna.Annice@college.harvard.edu', '2']
# ['Robinia', 'Shirberg', '15304763', 'Robinia.Shirberg@college.harvard.edu', '8']
# ['Carol-Jean', 'Elsinore', '13442638', 'Carol-Jean.Elsinore@college.harvard.edu', '11']
# ['Averyl', 'Dorine', '18551575', 'Averyl.Dorine@college.harvard.edu', '5']
# ['Anestassia', 'Hathaway', '19894017', 'Anestassia.Hathaway@college.harvard.edu', '5']
# ['Luci', 'Dulciana', '17658485', 'Luci.Dulciana@college.harvard.edu', '3']
# ['Jenda', 'Diann', '15279072', 'Jenda.Diann@college.harvard.edu', '9']
# ['Patricia', 'Schalles', '11917293', 'Patricia.Schalles@college.harvard.edu', '4']
# ['Bibby', 'Toor', '12441773', 'Bibby.Toor@college.harvard.edu', '4']
# ['Devina', 'Holtz', '14874114', 'Devina.Holtz@college.harvard.edu', '1']
# ['Zia', 'Jillane', '11583059', 'Zia.Jillane@college.harvard.edu', '4']
# ['Gertrud', 'Abbot', '18844206', 'Gertrud.Abbot@college.harvard.edu', '3']
# ['Judy', 'Kiersten', '14471867', 'Judy.Kiersten@college.harvard.edu', '1']
# ['Yolane', 'Thomasina', '13353635', 'Yolane.Thomasina@college.harvard.edu', '0']
# ['Morganica', 'Atcliffe', '18171957', 'Morganica.Atcliffe@college.harvard.edu', '3']
# ['Charlena', 'Nedrud', '17314209', 'Charlena.Nedrud@college.harvard.edu', '1']
# ['Charlena', 'Buffum', '11578825', 'Charlena.Buffum@college.harvard.edu', '7']
# ['Kassey', 'Screens', '16344805', 'Kassey.Screens@college.harvard.edu', '2']
# ['Lizzie', 'Brunell', '11196935', 'Lizzie.Brunell@college.harvard.edu', '5']
# ['Belva', 'Wenoa', '13029453', 'Belva.Wenoa@college.harvard.edu', '3']
# ['Tobe', 'Emmy', '18787384', 'Tobe.Emmy@college.harvard.edu', '4']
# ['Sheree', 'Plato', '16102308', 'Sheree.Plato@college.harvard.edu', '7']
# ['Dania', 'Boycey', '11614816', 'Dania.Boycey@college.harvard.edu', '9']
# ['Chickie', 'Chandler', '17953550', 'Chickie.Chandler@college.harvard.edu', '9']
# ['Sophia', 'Lasley', '14992235', 'Sophia.Lasley@college.harvard.edu', '5']
# ['Joane', 'Bouchard', '15634642', 'Joane.Bouchard@college.harvard.edu', '4']
# ['Ronna', 'Waldron', '17957371', 'Ronna.Waldron@college.harvard.edu', '4']
# ['Merci', 'Ailyn', '14009783', 'Merci.Ailyn@college.harvard.edu', '1']
# ['Fredericka', 'Grimbly', '13591891', 'Fredericka.Grimbly@college.harvard.edu', '3']
# ['Rochette', 'Genna', '19958152', 'Rochette.Genna@college.harvard.edu', '9']
# ['Heddie', 'Newell', '14364128', 'Heddie.Newell@college.harvard.edu', '0']
# ['Dode', 'Clywd', '11331372', 'Dode.Clywd@college.harvard.edu', '7']
# ['Brietta', 'Primalia', '16916977', 'Brietta.Primalia@college.harvard.edu', '8']
# ['Nicoli', 'Morrill', '18458190', 'Nicoli.Morrill@college.harvard.edu', '10']
# ['Misha', 'Cristi', '12765233', 'Misha.Cristi@college.harvard.edu', '7']
# ['Gretal', 'Septima', '14392954', 'Gretal.Septima@college.harvard.edu', '2']
# ['Christy', 'Iiette', '13392284', 'Christy.Iiette@college.harvard.edu', '8']
# ['Nickie', 'Suk', '14479374', 'Nickie.Suk@college.harvard.edu', '5']
# ['Annecorinne', 'Jerald', '14448714', 'Annecorinne.Jerald@college.harvard.edu', '6']
# ['Myriam', 'Sinegold', '15041739', 'Myriam.Sinegold@college.harvard.edu', '7']
# ['Agathe', 'Maribeth', '10512634', 'Agathe.Maribeth@college.harvard.edu', '11']
# ['Renie', 'Cadmar', '10999559', 'Renie.Cadmar@college.harvard.edu', '2']
# ['Eugine', 'Carbo', '13790515', 'Eugine.Carbo@college.harvard.edu', '1']
# ['Tersina', 'Roscoe', '10434851', 'Tersina.Roscoe@college.harvard.edu', '4']
# ['Kayla', 'Roumell', '16667305', 'Kayla.Roumell@college.harvard.edu', '0']
# ['Keelia', 'Tippets', '18861408', 'Keelia.Tippets@college.harvard.edu', '2']
# ['Elsie', 'Quinn', '10763714', 'Elsie.Quinn@college.harvard.edu', '3']
# ['Laurene', 'Daniele', '19854135', 'Laurene.Daniele@college.harvard.edu', '5']
# ['Siana', 'Valoniah', '10971840', 'Siana.Valoniah@college.harvard.edu', '4']
# ['Ardenia', 'Wareing', '11026377', 'Ardenia.Wareing@college.harvard.edu', '11']
# ['Willetta', 'Lay', '10596364', 'Willetta.Lay@college.harvard.edu', '11']
# ['Elfreda', 'Jethro', '16322570', 'Elfreda.Jethro@college.harvard.edu', '3']
# ['Helena', 'Zamora', '12541094', 'Helena.Zamora@college.harvard.edu', '4']
# ['Jessamyn', 'Ahab', '13090028', 'Jessamyn.Ahab@college.harvard.edu', '8']
# ['Marcy', 'Sharl', '11533090', 'Marcy.Sharl@college.harvard.edu', '11']
# ['Kathi', 'Emmy', '13607623', 'Kathi.Emmy@college.harvard.edu', '10']
# ['Jsandye', 'Tamar', '18483554', 'Jsandye.Tamar@college.harvard.edu', '0']
# ['Shandie', 'Wu', '19974709', 'Shandie.Wu@college.harvard.edu', '7']
# ['Daune', 'Lewes', '13258951', 'Daune.Lewes@college.harvard.edu', '7']
# ['Randa', 'Howlyn', '10495975', 'Randa.Howlyn@college.harvard.edu', '6']
# ['Misha', 'Tengdin', '12095147', 'Misha.Tengdin@college.harvard.edu', '0']
# ['Odessa', 'Ricarda', '14005932', 'Odessa.Ricarda@college.harvard.edu', '7']
# ['Olwen', 'Pauly', '12585710', 'Olwen.Pauly@college.harvard.edu', '5']
# ['Ivett', 'Marcellus', '16350342', 'Ivett.Marcellus@college.harvard.edu', '7']
# ['Marti', 'Flyn', '15811996', 'Marti.Flyn@college.harvard.edu', '2']
# ['Kristan', 'Standing', '19728411', 'Kristan.Standing@college.harvard.edu', '9']
# ['Nicoli', 'Rugen', '11798238', 'Nicoli.Rugen@college.harvard.edu', '2']
# ['Tybie', 'Roumell', '19703610', 'Tybie.Roumell@college.harvard.edu', '4']
# ['Natka', 'Zenas', '17293652', 'Natka.Zenas@college.harvard.edu', '4']
# ['Aigneis', 'Zeeba', '15499848', 'Aigneis.Zeeba@college.harvard.edu', '2']
# ['Jasmina', 'Wattenberg', '18112106', 'Jasmina.Wattenberg@college.harvard.edu', '6']
# ['Clarice', 'Kellby', '15104822', 'Clarice.Kellby@college.harvard.edu', '11']
# ['Frances', 'Joni', '10462931', 'Frances.Joni@college.harvard.edu', '1']
# ['Roseline', 'Belanger', '13040203', 'Roseline.Belanger@college.harvard.edu', '10']
# ['Emmey', 'Bryna', '19613038', 'Emmey.Bryna@college.harvard.edu', '9']
# ['Josephine', 'Chaing', '10018430', 'Josephine.Chaing@college.harvard.edu', '1']
# ['Dulcinea', 'Septima', '13505835', 'Dulcinea.Septima@college.harvard.edu', '4']
# ['Hermione', 'Valerio', '12033707', 'Hermione.Valerio@college.harvard.edu', '0']
# ['Glenda', 'Carmena', '16836397', 'Glenda.Carmena@college.harvard.edu', '10']
# ['Lacie', 'Hartnett', '18592300', 'Lacie.Hartnett@college.harvard.edu', '1']
# ['Gilligan', 'Yusuk', '10995865', 'Gilligan.Yusuk@college.harvard.edu', '0']
# ['Raf', 'Sprage', '15721990', 'Raf.Sprage@college.harvard.edu', '2']
# ['Nollie', 'Soneson', '11577153', 'Nollie.Soneson@college.harvard.edu', '5']
# ['Sybille', 'Merriott', '10431764', 'Sybille.Merriott@college.harvard.edu', '9']
# ['Alia', 'Ax', '18292267', 'Alia.Ax@college.harvard.edu', '2']
# ['Linet', 'Rosette', '17390813', 'Linet.Rosette@college.harvard.edu', '3']
# ['Olivette', 'Sprage', '12803689', 'Olivette.Sprage@college.harvard.edu', '3']
# ['Kylynn', 'Garbe', '11890866', 'Kylynn.Garbe@college.harvard.edu', '6']
# ['Sara-Ann', 'Leopold', '14818968', 'Sara-Ann.Leopold@college.harvard.edu', '11']
# ['Orelia', 'Diann', '16575256', 'Orelia.Diann@college.harvard.edu', '4']
# ['Ethel', 'Ariella', '13239167', 'Ethel.Ariella@college.harvard.edu', '3']
# ['Shauna', 'Docilla', '15250156', 'Shauna.Docilla@college.harvard.edu', '6']
# ['Bettine', 'Norrie', '19658917', 'Bettine.Norrie@college.harvard.edu', '0']
# ['Cristabel', 'Shields', '11557985', 'Cristabel.Shields@college.harvard.edu', '7']
# ['Gabi', 'Drisko', '12313850', 'Gabi.Drisko@college.harvard.edu', '4']
# ['Allis', 'Glenden', '18548650', 'Allis.Glenden@college.harvard.edu', '11']
# ['Beatriz', 'Stover', '15517463', 'Beatriz.Stover@college.harvard.edu', '9']
# ['Phedra', 'Daegal', '14322765', 'Phedra.Daegal@college.harvard.edu', '5']
# ['Nerta', 'Maroney', '14711834', 'Nerta.Maroney@college.harvard.edu', '9']
# ['Lorne', 'Schenck', '11660791', 'Lorne.Schenck@college.harvard.edu', '8']
# ['Tressa', 'Roscoe', '18800777', 'Tressa.Roscoe@college.harvard.edu', '5']
# ['Jere', 'Rogerio', '13250942', 'Jere.Rogerio@college.harvard.edu', '9']
# ['Nannie', 'Zetta', '16190963', 'Nannie.Zetta@college.harvard.edu', '2']
# ['Chloris', 'Dyche', '19984627', 'Chloris.Dyche@college.harvard.edu', '2']
# ['Julieta', 'Sheng', '14858247', 'Julieta.Sheng@college.harvard.edu', '2']
# ['Jasmina', 'Ader', '14429841', 'Jasmina.Ader@college.harvard.edu', '1']
# ['Priscilla', 'Vale', '13265824', 'Priscilla.Vale@college.harvard.edu', '2']
# ['Clementine', 'Granoff', '10504852', 'Clementine.Granoff@college.harvard.edu', '4']
# ['Brena', 'Huggins', '11493336', 'Brena.Huggins@college.harvard.edu', '10']
# ['Xylina', 'Yorick', '18703690', 'Xylina.Yorick@college.harvard.edu', '4']
# ['Cordi', 'Bronk', '13062118', 'Cordi.Bronk@college.harvard.edu', '7']
# ['Claudina', 'Artie', '14132861', 'Claudina.Artie@college.harvard.edu', '3']
# ['Laurene', 'Zenas', '16077152', 'Laurene.Zenas@college.harvard.edu', '4']
# ['Raf', 'Alice', '14741315', 'Raf.Alice@college.harvard.edu', '5']
# ['Mady', 'Kunin', '16516136', 'Mady.Kunin@college.harvard.edu', '6']
# ['Priscilla', 'Blisse', '17187246', 'Priscilla.Blisse@college.harvard.edu', '5']
# ['Paola', 'Burnside', '16692120', 'Paola.Burnside@college.harvard.edu', '5']
# ['Genevra', 'Harriman', '17355758', 'Genevra.Harriman@college.harvard.edu', '11']
# ['Nickie', 'Tatianas', '10386375', 'Nickie.Tatianas@college.harvard.edu', '8']
# ['Elvira', 'Thema', '12627778', 'Elvira.Thema@college.harvard.edu', '2']
# ['Blondelle', 'Fink', '12658378', 'Blondelle.Fink@college.harvard.edu', '3']
# ['Janenna', 'Colp', '15106295', 'Janenna.Colp@college.harvard.edu', '10']
# ['Benita', 'Joli', '10084672', 'Benita.Joli@college.harvard.edu', '11']
# ['Teriann', 'Sancho', '15442589', 'Teriann.Sancho@college.harvard.edu', '1']
# ['Giustina', 'Zrike', '10243008', 'Giustina.Zrike@college.harvard.edu', '6']
# ['Dione', 'Rad', '17225979', 'Dione.Rad@college.harvard.edu', '8']
# ['Althea', 'Ingra', '14546027', 'Althea.Ingra@college.harvard.edu', '1']
# ['Rosanne', 'Pierette', '14774090', 'Rosanne.Pierette@college.harvard.edu', '11']
# ['Kaja', 'Mike', '15552390', 'Kaja.Mike@college.harvard.edu', '2']
# ['Siana', 'Annice', '13442797', 'Siana.Annice@college.harvard.edu', '2']
# ['Winny', 'Tryck', '14652923', 'Winny.Tryck@college.harvard.edu', '10']
# ['Sallie', 'Beebe', '12166088', 'Sallie.Beebe@college.harvard.edu', '11']
# ['Alex', 'Clie', '11202302', 'Alex.Clie@college.harvard.edu', '11']
# ['Donnie', 'Mata', '11161830', 'Donnie.Mata@college.harvard.edu', '5']
# ['Marguerite', 'Uird', '10617958', 'Marguerite.Uird@college.harvard.edu', '10']
# ['Tracey', 'Ammann', '17612272', 'Tracey.Ammann@college.harvard.edu', '7']
# ['Vinita', 'Tristram', '17439041', 'Vinita.Tristram@college.harvard.edu', '0']
# ['Gwenneth', 'Pacorro', '16307471', 'Gwenneth.Pacorro@college.harvard.edu', '7']
# ['Cissiee', 'Ehrman', '16000436', 'Cissiee.Ehrman@college.harvard.edu', '3']
# ['Albertina', 'Peg', '16155043', 'Albertina.Peg@college.harvard.edu', '1']
# ['Ayn', 'Tjon', '11108293', 'Ayn.Tjon@college.harvard.edu', '3']
# ['Lila', 'Fink', '12762578', 'Lila.Fink@college.harvard.edu', '5']
# ['Elyssa', 'Ferrell', '14483367', 'Elyssa.Ferrell@college.harvard.edu', '2']
# ['Marjie', 'Tristram', '18960145', 'Marjie.Tristram@college.harvard.edu', '7']
# ['Maisey', 'Gilbertson', '10211491', 'Maisey.Gilbertson@college.harvard.edu', '2']
# ['Lorenza', 'Dearborn', '18290415', 'Lorenza.Dearborn@college.harvard.edu', '9']
# ['Sam', 'Tound', '13871481', 'Sam.Tound@college.harvard.edu', '11']
# ['Jobi', 'Gusella', '15831002', 'Jobi.Gusella@college.harvard.edu', '10']
# ['Sabina', 'Iiette', '14909226', 'Sabina.Iiette@college.harvard.edu', '3']
# ['Fanchon', 'Lewes', '19289772', 'Fanchon.Lewes@college.harvard.edu', '2']
# ['Bettine', 'Niccolo', '12587420', 'Bettine.Niccolo@college.harvard.edu', '3']
# ['Kittie', 'Seumas', '17227745', 'Kittie.Seumas@college.harvard.edu', '11']
# ['Mireielle', 'Ardra', '12726659', 'Mireielle.Ardra@college.harvard.edu', '4']
# ['Chastity', 'Sabella', '13299610', 'Chastity.Sabella@college.harvard.edu', '11']
# ['Averyl', 'Fredi', '10926797', 'Averyl.Fredi@college.harvard.edu', '11']
# ['Tabbatha', 'Nore', '18599543', 'Tabbatha.Nore@college.harvard.edu', '10']
# ['Annecorinne', 'Marijo', '15561593', 'Annecorinne.Marijo@college.harvard.edu', '8']
# ['Brena', 'Kesley', '19274804', 'Brena.Kesley@college.harvard.edu', '11']
# ['Blake', 'Arathorn', '18718806', 'Blake.Arathorn@college.harvard.edu', '3']
# ['Starla', 'Koehler', '12057217', 'Starla.Koehler@college.harvard.edu', '8']
# ['Lila', 'Shanley', '12740931', 'Lila.Shanley@college.harvard.edu', '8']
# ['Lorne', 'Boehike', '11213265', 'Lorne.Boehike@college.harvard.edu', '11']
# ['Adriana', 'McClimans', '16487544', 'Adriana.McClimans@college.harvard.edu', '5']
# ['Charlena', 'Saint', '18206509', 'Charlena.Saint@college.harvard.edu', '10']
# ['Alleen', 'Rosemary', '10161183', 'Alleen.Rosemary@college.harvard.edu', '0']
# ['Fernande', 'Nester', '16794516', 'Fernande.Nester@college.harvard.edu', '8']
# ['Nelle', 'Cassius', '12046452', 'Nelle.Cassius@college.harvard.edu', '1']
# ['Keelia', 'Chinua', '16704646', 'Keelia.Chinua@college.harvard.edu', '4']
# ['Brietta', 'Bartlett', '11396882', 'Brietta.Bartlett@college.harvard.edu', '1']
# ['Viki', 'Dahlia', '14758454', 'Viki.Dahlia@college.harvard.edu', '1']
# ['Bertine', 'Newell', '19032590', 'Bertine.Newell@college.harvard.edu', '6']
# ['Rozele', 'Cleavland', '15945516', 'Rozele.Cleavland@college.harvard.edu', '5']
# ['Beth', 'Kress', '15596629', 'Beth.Kress@college.harvard.edu', '6']
# ['Neila', 'Haymes', '16440834', 'Neila.Haymes@college.harvard.edu', '5']
# ['Dotty', 'Dex', '16624239', 'Dotty.Dex@college.harvard.edu', '2']
# ['Cindelyn', 'Joni', '16161089', 'Cindelyn.Joni@college.harvard.edu', '0']
# ['Doro', 'Dom', '17592122', 'Doro.Dom@college.harvard.edu', '0']
# ['Bibby', 'Halsey', '19785346', 'Bibby.Halsey@college.harvard.edu', '2']
# ['Jacenta', 'Lory', '14648651', 'Jacenta.Lory@college.harvard.edu', '4']
# ['Kylynn', 'Warthman', '13782079', 'Kylynn.Warthman@college.harvard.edu', '6']
# ['Ruthe', 'Dannye', '17566782', 'Ruthe.Dannye@college.harvard.edu', '9']
# ['Estell', 'Swanhildas', '15322491', 'Estell.Swanhildas@college.harvard.edu', '6']
# ['Jaclyn', 'Ioab', '12898682', 'Jaclyn.Ioab@college.harvard.edu', '9']
# ['Rosene', 'Artie', '14866879', 'Rosene.Artie@college.harvard.edu', '8']
# ['Ekaterina', 'Salvidor', '15037295', 'Ekaterina.Salvidor@college.harvard.edu', '2']
# ['Deedee', 'Stanwood', '17175615', 'Deedee.Stanwood@college.harvard.edu', '1']
# ['Rivalee', 'Willie', '15107055', 'Rivalee.Willie@college.harvard.edu', '7']
# ['Atlanta', 'Elbertina', '19463693', 'Atlanta.Elbertina@college.harvard.edu', '7']
# ['Jerry', 'Adamsen', '13635100', 'Jerry.Adamsen@college.harvard.edu', '2']
# ['Constance', 'Gilbertson', '19270895', 'Constance.Gilbertson@college.harvard.edu', '8']
# ['Agathe', 'Zachary', '10057785', 'Agathe.Zachary@college.harvard.edu', '7']
# ['Ottilie', 'Pond', '19601509', 'Ottilie.Pond@college.harvard.edu', '10']
# ['Korrie', 'Berl', '16614900', 'Korrie.Berl@college.harvard.edu', '4']
# ['Bibby', 'Lissi', '16096602', 'Bibby.Lissi@college.harvard.edu', '5']
# ['Ellette', 'Ellord', '17926648', 'Ellette.Ellord@college.harvard.edu', '1']
# ['Dorene', 'Casimir', '14420637', 'Dorene.Casimir@college.harvard.edu', '8']
# ['Vevay', 'Sancho', '15364919', 'Vevay.Sancho@college.harvard.edu', '6']
# ['Raina', 'Kristi', '19694978', 'Raina.Kristi@college.harvard.edu', '1']
# ['Justinn', 'Mallon', '18157448', 'Justinn.Mallon@college.harvard.edu', '5']
# ['Raquela', 'Lenny', '18924933', 'Raquela.Lenny@college.harvard.edu', '9']
# ['Rosanne', 'Graig', '13501056', 'Rosanne.Graig@college.harvard.edu', '11']
# ['Devina', 'Fontana', '15837609', 'Devina.Fontana@college.harvard.edu', '4']
# ['Ann-Marie', 'Eldrid', '17484776', 'Ann-Marie.Eldrid@college.harvard.edu', '6']
# ['Jeanna', 'Velick', '10123917', 'Jeanna.Velick@college.harvard.edu', '9']
# ['Keelia', 'Cordi', '19066481', 'Keelia.Cordi@college.harvard.edu', '3']
# ['Merle', 'Ioab', '19055556', 'Merle.Ioab@college.harvard.edu', '1']
# ['Corly', 'Stelle', '13629300', 'Corly.Stelle@college.harvard.edu', '3']
# ['Hannis', 'Arquit', '11659272', 'Hannis.Arquit@college.harvard.edu', '7']
# ['Jan', 'Killigrew', '12211147', 'Jan.Killigrew@college.harvard.edu', '0']
# ['Amalie', 'Jena', '15711842', 'Amalie.Jena@college.harvard.edu', '6']
# ['Michaelina', 'Decato', '16556965', 'Michaelina.Decato@college.harvard.edu', '5']
# ['Belinda', 'Iiette', '13087109', 'Belinda.Iiette@college.harvard.edu', '7']
# ['Cissiee', 'Emmy', '12260660', 'Cissiee.Emmy@college.harvard.edu', '5']
# ['Ezmeralda', 'Lindemann', '19575575', 'Ezmeralda.Lindemann@college.harvard.edu', '0']
# ['Bobinette', 'Matthew', '15380655', 'Bobinette.Matthew@college.harvard.edu', '7']
# ['Alia', 'Wenoa', '13934131', 'Alia.Wenoa@college.harvard.edu', '1']
# ['Leia', 'Nance', '17649524', 'Leia.Nance@college.harvard.edu', '0']
# ['Roberta', 'Truc', '10732636', 'Roberta.Truc@college.harvard.edu', '5']
# ['Carol-Jean', 'Eno', '15376129', 'Carol-Jean.Eno@college.harvard.edu', '10']
# ['Averyl', 'Brieta', '15653824', 'Averyl.Brieta@college.harvard.edu', '11']
# ['Dale', 'Podvin', '15623256', 'Dale.Podvin@college.harvard.edu', '10']
# ['Frieda', "O'Rourke", '17981599', "Frieda.O'Rourke@college.harvard.edu", '8']
# ['Linzy', 'Maribeth', '18033621', 'Linzy.Maribeth@college.harvard.edu', '0']
# ['Laure', 'Aloise', '13243090', 'Laure.Aloise@college.harvard.edu', '6']
# ['Evaleen', 'Wolfgram', '13940303', 'Evaleen.Wolfgram@college.harvard.edu', '7']
# ['Nariko', 'Sallyann', '18953266', 'Nariko.Sallyann@college.harvard.edu', '1']
# ['Aurelie', 'Ortrude', '10158974', 'Aurelie.Ortrude@college.harvard.edu', '4']
# ['Minne', 'Thornburg', '10037617', 'Minne.Thornburg@college.harvard.edu', '2']
# ['Silvana', 'McClimans', '11514978', 'Silvana.McClimans@college.harvard.edu', '8']
# ['Tori', 'Emmaline', '14764368', 'Tori.Emmaline@college.harvard.edu', '0']
# ['Reeba', 'Wyn', '18793626', 'Reeba.Wyn@college.harvard.edu', '4']
# ['Brandise', 'Delila', '11340377', 'Brandise.Delila@college.harvard.edu', '7']
# ['Siana', 'Soneson', '17998677', 'Siana.Soneson@college.harvard.edu', '7']
# ['Fredericka', 'Emanuel', '16334739', 'Fredericka.Emanuel@college.harvard.edu', '4']
# ['Valeda', 'Fiester', '14512673', 'Valeda.Fiester@college.harvard.edu', '2']
# ['Rosabelle', 'Lymann', '12009571', 'Rosabelle.Lymann@college.harvard.edu', '8']
# ['Xylina', 'Guildroy', '16246904', 'Xylina.Guildroy@college.harvard.edu', '2']
# ['Mady', 'Larochelle', '14035179', 'Mady.Larochelle@college.harvard.edu', '1']
# ['Selia', 'Llovera', '14302923', 'Selia.Llovera@college.harvard.edu', '9']
# ['Joelly', "O'Carroll", '14035190', "Joelly.O'Carroll@college.harvard.edu", '5']
# ['Alex', 'Modie', '12824975', 'Alex.Modie@college.harvard.edu', '9']
# ['Betta', 'Zachary', '10062689', 'Betta.Zachary@college.harvard.edu', '1']
# ['Josephine', 'Wesle', '11985936', 'Josephine.Wesle@college.harvard.edu', '5']
# ['Aeriela', 'Maribeth', '16336632', 'Aeriela.Maribeth@college.harvard.edu', '2']
# ['Ivett', 'Rona', '19991106', 'Ivett.Rona@college.harvard.edu', '10']
# ['Clary', 'Stevy', '14691987', 'Clary.Stevy@college.harvard.edu', '11']
# ['Zondra', 'Kathie', '19999567', 'Zondra.Kathie@college.harvard.edu', '3']
# ['Susette', 'Elephus', '15826857', 'Susette.Elephus@college.harvard.edu', '1']
# ['Britte', 'Yate', '12685480', 'Britte.Yate@college.harvard.edu', '6']
# ['Edyth', 'Concha', '19745556', 'Edyth.Concha@college.harvard.edu', '10']
# ['Thalia', 'Atonsah', '13035523', 'Thalia.Atonsah@college.harvard.edu', '2']
# ['Marti', 'Slifka', '12227793', 'Marti.Slifka@college.harvard.edu', '9']
# ['Gilda', 'Gillan', '14094779', 'Gilda.Gillan@college.harvard.edu', '8']
# ['Lyssa', 'Timon', '19679574', 'Lyssa.Timon@college.harvard.edu', '4']
# ['Vonny', 'Behre', '10551097', 'Vonny.Behre@college.harvard.edu', '5']
# ['Nollie', 'Clie', '12582290', 'Nollie.Clie@college.harvard.edu', '8']
# ['Rubie', 'Allare', '17495367', 'Rubie.Allare@college.harvard.edu', '5']
# ['Kamilah', 'Margret', '14691040', 'Kamilah.Margret@college.harvard.edu', '4']
# ['Audrie', 'Weaks', '11069346', 'Audrie.Weaks@college.harvard.edu', '8']
# ['Latisha', 'Fink', '18665119', 'Latisha.Fink@college.harvard.edu', '11']
# ['Belva', 'Hylan', '15664126', 'Belva.Hylan@college.harvard.edu', '7']
# ['Kary', 'Valerio', '17362838', 'Kary.Valerio@college.harvard.edu', '11']
# ['Fayre', 'Dawkins', '12600497', 'Fayre.Dawkins@college.harvard.edu', '10']
# ['Katleen', 'Norvol', '16415829', 'Katleen.Norvol@college.harvard.edu', '4']
# ['Angela', 'Harned', '16145536', 'Angela.Harned@college.harvard.edu', '7']
# ['Lanae', 'Arley', '18467116', 'Lanae.Arley@college.harvard.edu', '4']
# ['Marline', 'Himelman', '18829950', 'Marline.Himelman@college.harvard.edu', '4']
# ['Jessamyn', 'Konyn', '11424171', 'Jessamyn.Konyn@college.harvard.edu', '2']
# ['Shell', 'Elvyn', '18673040', 'Shell.Elvyn@college.harvard.edu', '5']
# ['Fred', 'Stuart', '16955982', 'Fred.Stuart@college.harvard.edu', '6']
# ['Lesly', 'Serilda', '14253166', 'Lesly.Serilda@college.harvard.edu', '11']
# ['Violet', 'Pearse', '16987852', 'Violet.Pearse@college.harvard.edu', '4']
# ['Marline', 'Myrilla', '15466072', 'Marline.Myrilla@college.harvard.edu', '2']
# ['Evita', 'Vary', '14410079', 'Evita.Vary@college.harvard.edu', '8']
# ['Sashenka', 'Dudley', '19374537', 'Sashenka.Dudley@college.harvard.edu', '3']
# ['Anallese', 'Goth', '17927182', 'Anallese.Goth@college.harvard.edu', '3']
# ['Louella', 'Eachern', '11791568', 'Louella.Eachern@college.harvard.edu', '3']
# ['Hildegaard', 'Dearborn', '16787469', 'Hildegaard.Dearborn@college.harvard.edu', '3']
# ['Amalie', 'Alabaster', '16930954', 'Amalie.Alabaster@college.harvard.edu', '9']
# ['Dale', 'Ries', '15313867', 'Dale.Ries@college.harvard.edu', '8']
# ['Briney', 'Hoban', '17562479', 'Briney.Hoban@college.harvard.edu', '6']
# ['Deane', 'Malvino', '15124670', 'Deane.Malvino@college.harvard.edu', '0']
# ['Karlee', 'Freddi', '12962460', 'Karlee.Freddi@college.harvard.edu', '7']
# ['Reeba', 'Anyah', '13425993', 'Reeba.Anyah@college.harvard.edu', '11']
# ['Netty', 'Jagir', '17321044', 'Netty.Jagir@college.harvard.edu', '9']
# ['Sissy', 'Nerita', '11476996', 'Sissy.Nerita@college.harvard.edu', '4']
# ['Iseabal', 'Bashemeth', '17926064', 'Iseabal.Bashemeth@college.harvard.edu', '11']
# ['Tracey', 'Hartnett', '12769868', 'Tracey.Hartnett@college.harvard.edu', '11']
# ['Myriam', 'Fabiola', '13646566', 'Myriam.Fabiola@college.harvard.edu', '6']
# ['Zsa Zsa', 'Lynn', '17628953', 'Zsa Zsa.Lynn@college.harvard.edu', '9']
# ['Loree', 'Damarra', '17314349', 'Loree.Damarra@college.harvard.edu', '10']
# ['Ardys', 'Ursulette', '19257991', 'Ardys.Ursulette@college.harvard.edu', '6']
# ['Aimil', 'Reneta', '11416674', 'Aimil.Reneta@college.harvard.edu', '7']
# ['Antonietta', 'Wenoa', '14303360', 'Antonietta.Wenoa@college.harvard.edu', '1']
# ['Shauna', 'Jillane', '19604214', 'Shauna.Jillane@college.harvard.edu', '4']
# ['Nyssa', 'Lorain', '11661745', 'Nyssa.Lorain@college.harvard.edu', '3']
# ['Anica', 'Yusuk', '17348593', 'Anica.Yusuk@college.harvard.edu', '2']
# ['Rosabelle', 'Haerr', '14713897', 'Rosabelle.Haerr@college.harvard.edu', '1']
# ['Zaria', 'Hollingsworth', '18200710', 'Zaria.Hollingsworth@college.harvard.edu', '7']
# ['Betta', 'Cullin', '14207386', 'Betta.Cullin@college.harvard.edu', '9']
# ['Rhoda', 'Mathilde', '11529282', 'Rhoda.Mathilde@college.harvard.edu', '5']
# ['Camile', 'Noelyn', '15734485', 'Camile.Noelyn@college.harvard.edu', '10']
# ['Claudina', 'Eben', '15516426', 'Claudina.Eben@college.harvard.edu', '0']
# ['Caryl', 'Gabrielli', '11664492', 'Caryl.Gabrielli@college.harvard.edu', '0']
# ['Jinny', 'Haerr', '14135401', 'Jinny.Haerr@college.harvard.edu', '8']
# ['Riannon', 'Redmond', '19596885', 'Riannon.Redmond@college.harvard.edu', '0']
# ['Vere', 'Mitzi', '15866728', 'Vere.Mitzi@college.harvard.edu', '2']
# ['Lynnea', 'Daveta', '15787314', 'Lynnea.Daveta@college.harvard.edu', '8']
# ['Binny', 'Medrek', '17630510', 'Binny.Medrek@college.harvard.edu', '11']
# ['Claresta', 'Chrystel', '18203756', 'Claresta.Chrystel@college.harvard.edu', '5']
# ['Jessy', 'Justinn', '15859306', 'Jessy.Justinn@college.harvard.edu', '6']
# ['Raina', 'Jammal', '13224952', 'Raina.Jammal@college.harvard.edu', '2']
# ['Lolita', 'Therine', '11513216', 'Lolita.Therine@college.harvard.edu', '2']
# ['Aigneis', 'Craggie', '12628083', 'Aigneis.Craggie@college.harvard.edu', '0']
# ['Renie', 'Heisel', '15944090', 'Renie.Heisel@college.harvard.edu', '3']
# ['Magdalena', 'Yate', '16477699', 'Magdalena.Yate@college.harvard.edu', '0']
# ['Dacia', 'Harriman', '13555102', 'Dacia.Harriman@college.harvard.edu', '9']
# ['Josephine', 'Grosz', '10004157', 'Josephine.Grosz@college.harvard.edu', '2']
# ['Aaren', 'Timon', '18630067', 'Aaren.Timon@college.harvard.edu', '0']
# ['Jennica', 'Pettiford', '11417817', 'Jennica.Pettiford@college.harvard.edu', '3']
# ['Cristabel', 'Cadmar', '14805294', 'Cristabel.Cadmar@college.harvard.edu', '11']
# ['Claresta', 'Nahum', '10315953', 'Claresta.Nahum@college.harvard.edu', '0']
# ['Doralynne', 'Baylor', '14077800', 'Doralynne.Baylor@college.harvard.edu', '2']
# ['Brietta', 'Morgun', '17641524', 'Brietta.Morgun@college.harvard.edu', '3']
# ['Ardenia', 'Chobot', '14627170', 'Ardenia.Chobot@college.harvard.edu', '2']
# ['Tarra', 'Emmy', '19126333', 'Tarra.Emmy@college.harvard.edu', '0']
# ['Ileana', 'Michella', '14244904', 'Ileana.Michella@college.harvard.edu', '5']
# ['Julieta', 'Dash', '12116605', 'Julieta.Dash@college.harvard.edu', '10']
# ['Beverley', 'Wooster', '12413095', 'Beverley.Wooster@college.harvard.edu', '7']
# ['Luci', 'Corabella', '17742824', 'Luci.Corabella@college.harvard.edu', '1']
# ['Lila', 'Bergman', '18979745', 'Lila.Bergman@college.harvard.edu', '5']
# ['Patricia', 'Alejoa', '16214403', 'Patricia.Alejoa@college.harvard.edu', '2']
# ['Mathilda', 'Mauer', '19854714', 'Mathilda.Mauer@college.harvard.edu', '0']
# ['Ottilie', 'Codding', '12467150', 'Ottilie.Codding@college.harvard.edu', '4']
# ['Teddie', 'Anestassia', '13867822', 'Teddie.Anestassia@college.harvard.edu', '0']
# ['Berta', 'Ade', '13418125', 'Berta.Ade@college.harvard.edu', '6']
# ['Teriann', 'Dorcy', '17891433', 'Teriann.Dorcy@college.harvard.edu', '3']
# ['Nananne', "O'Carroll", '15923124', "Nananne.O'Carroll@college.harvard.edu", '9']
# ['Brynna', 'Lunsford', '11392410', 'Brynna.Lunsford@college.harvard.edu', '3']
# ['Ida', 'Shuler', '19521623', 'Ida.Shuler@college.harvard.edu', '5']
# ['Aimil', 'Tacye', '15221282', 'Aimil.Tacye@college.harvard.edu', '2']
# ['Monika', 'Allare', '16411504', 'Monika.Allare@college.harvard.edu', '10']
# ['Roxane', 'Pitt', '18385898', 'Roxane.Pitt@college.harvard.edu', '4']
# ['Elbertina', 'Chesna', '13813191', 'Elbertina.Chesna@college.harvard.edu', '10']
# ['Malina', 'Hessler', '19374064', 'Malina.Hessler@college.harvard.edu', '7']
# ['Eolanda', 'Elvyn', '14220399', 'Eolanda.Elvyn@college.harvard.edu', '1']
# ['Adore', 'Cynar', '13732698', 'Adore.Cynar@college.harvard.edu', '5']
# ['Dale', 'Blake', '19847603', 'Dale.Blake@college.harvard.edu', '9']
# ['Cam', 'Rodmann', '14523012', 'Cam.Rodmann@college.harvard.edu', '8']
# ['Roz', 'Magnolia', '13477994', 'Roz.Magnolia@college.harvard.edu', '6']
# ['Beatriz', 'Clara', '15921985', 'Beatriz.Clara@college.harvard.edu', '1']
# ['Caressa', 'Granoff', '10940599', 'Caressa.Granoff@college.harvard.edu', '10']
# ['Codie', 'Gregrory', '15673708', 'Codie.Gregrory@college.harvard.edu', '0']
# ['Mathilda', 'Cosenza', '13908008', 'Mathilda.Cosenza@college.harvard.edu', '7']
# ['Bobinette', 'Jagir', '17701556', 'Bobinette.Jagir@college.harvard.edu', '3']
# ['Lacie', 'Velick', '16440009', 'Lacie.Velick@college.harvard.edu', '1']
# ['Carly', 'Hebner', '11834210', 'Carly.Hebner@college.harvard.edu', '3']
# ['Molli', 'Belldas', '17872710', 'Molli.Belldas@college.harvard.edu', '7']
# ['Edith', 'Niles', '14699985', 'Edith.Niles@college.harvard.edu', '6']
# ['Yetty', 'Ralfston', '17852222', 'Yetty.Ralfston@college.harvard.edu', '4']
# ['Briney', 'Means', '19899421', 'Briney.Means@college.harvard.edu', '2']
# ['Ida', 'Linehan', '18798588', 'Ida.Linehan@college.harvard.edu', '7']
# ['Gwyneth', 'Juliet', '13474778', 'Gwyneth.Juliet@college.harvard.edu', '10']
# ['Joleen', 'Madelene', '18827190', 'Joleen.Madelene@college.harvard.edu', '5']
# ['Lory', 'Kat', '11308726', 'Lory.Kat@college.harvard.edu', '8']
# ['Wilma', 'Kamaria', '14830012', 'Wilma.Kamaria@college.harvard.edu', '2']
# ['Gloria', 'Amadas', '12220298', 'Gloria.Amadas@college.harvard.edu', '7']
# ['Krystle', 'Vins', '16731455', 'Krystle.Vins@college.harvard.edu', '10']
# ['Jessy', 'Rodmann', '11879077', 'Jessy.Rodmann@college.harvard.edu', '1']
# ['Winny', 'Gerge', '16197304', 'Winny.Gerge@college.harvard.edu', '0']
# ['Aimil', 'Constancy', '10888866', 'Aimil.Constancy@college.harvard.edu', '4']
# ['Chere', 'Neva', '10493179', 'Chere.Neva@college.harvard.edu', '10']
# ['Beatriz', 'Helve', '10348066', 'Beatriz.Helve@college.harvard.edu', '0']
# ['Hannis', 'Huggins', '18598141', 'Hannis.Huggins@college.harvard.edu', '4']
# ['Edyth', 'Nisbet', '10370788', 'Edyth.Nisbet@college.harvard.edu', '11']
# ['Mahalia', 'Hilbert', '15163827', 'Mahalia.Hilbert@college.harvard.edu', '6']
# ['Carmencita', 'Mullane', '10923218', 'Carmencita.Mullane@college.harvard.edu', '1']
# ['Blake', 'Fredi', '12897689', 'Blake.Fredi@college.harvard.edu', '2']
# ['Malina', 'Seligman', '10541114', 'Malina.Seligman@college.harvard.edu', '0']
# ['Annora', 'Riva', '16776558', 'Annora.Riva@college.harvard.edu', '7']
# ['Rubie', 'Sandye', '18111496', 'Rubie.Sandye@college.harvard.edu', '8']
# ['Adelle', 'Wandie', '17206590', 'Adelle.Wandie@college.harvard.edu', '9']
# ['Sue', 'Arley', '14858721', 'Sue.Arley@college.harvard.edu', '5']
# ['Melisent', 'Xerxes', '15057567', 'Melisent.Xerxes@college.harvard.edu', '7']
# ['Romona', 'Gilbertson', '19250888', 'Romona.Gilbertson@college.harvard.edu', '7']
# ['Modestia', 'Center', '12591112', 'Modestia.Center@college.harvard.edu', '1']
# ['Berget', 'Charity', '14398281', 'Berget.Charity@college.harvard.edu', '9']
# ['Susette', 'Kiersten', '14398052', 'Susette.Kiersten@college.harvard.edu', '7']
# ['Millie', 'Johanna', '14217321', 'Millie.Johanna@college.harvard.edu', '3']
# ['Lacie', 'Phyllis', '18497809', 'Lacie.Phyllis@college.harvard.edu', '10']
# ['Gerrie', 'Taam', '12137298', 'Gerrie.Taam@college.harvard.edu', '2']
# ['Riannon', 'Raseda', '13800219', 'Riannon.Raseda@college.harvard.edu', '8']
# ['Farrah', 'Persse', '15121382', 'Farrah.Persse@college.harvard.edu', '6']
# ['Cordi', 'Nester', '15385272', 'Cordi.Nester@college.harvard.edu', '4']
# ['Henriette', 'Manolo', '10578825', 'Henriette.Manolo@college.harvard.edu', '11']
# ['Almeta', 'Erich', '15984018', 'Almeta.Erich@college.harvard.edu', '9']
# ['Heddie', 'Drus', '14151283', 'Heddie.Drus@college.harvard.edu', '4']
# ['Wynne', 'Orpah', '18984001', 'Wynne.Orpah@college.harvard.edu', '7']
# ['Marjie', 'Johanna', '16153602', 'Marjie.Johanna@college.harvard.edu', '8']
# ['Miquela', 'Koziara', '17633129', 'Miquela.Koziara@college.harvard.edu', '7']
# ['Deedee', 'Dunkin', '10220203', 'Deedee.Dunkin@college.harvard.edu', '0']
# ['Halette', 'Smitt', '16408364', 'Halette.Smitt@college.harvard.edu', '7']
# ['Valli', 'Cath', '18748627', 'Valli.Cath@college.harvard.edu', '7']
# ['Modestia', 'Hollingsworth', '10118286', 'Modestia.Hollingsworth@college.harvard.edu', '4']
# ['Genevra', 'Pulsifer', '18354386', 'Genevra.Pulsifer@college.harvard.edu', '5']
# ['Cyndie', 'Flita', '14725651', 'Cyndie.Flita@college.harvard.edu', '0']
# ['Sara-Ann', 'Kirbee', '16507157', 'Sara-Ann.Kirbee@college.harvard.edu', '5']
# ['Oona', 'Flita', '11679528', 'Oona.Flita@college.harvard.edu', '5']
# ['Sadie', 'Guildroy', '13973494', 'Sadie.Guildroy@college.harvard.edu', '0']
# ['Susan', 'Grosz', '19302731', 'Susan.Grosz@college.harvard.edu', '9']
# ['Georgina', 'Norrie', '16152376', 'Georgina.Norrie@college.harvard.edu', '5']
# ['Cam', 'Roumell', '16349829', 'Cam.Roumell@college.harvard.edu', '4']
# ['Consuela', 'Haerr', '13072923', 'Consuela.Haerr@college.harvard.edu', '3']
# ['Rori', 'Hebner', '19289418', 'Rori.Hebner@college.harvard.edu', '6']
# ['Georgetta', 'Linehan', '15549268', 'Georgetta.Linehan@college.harvard.edu', '1']
# ['Tracey', 'Kenney', '12275100', 'Tracey.Kenney@college.harvard.edu', '5']
# ['Elfreda', 'Roarke', '17265644', 'Elfreda.Roarke@college.harvard.edu', '6']
# ['Linet', 'Brian', '13502166', 'Linet.Brian@college.harvard.edu', '10']
# ['Melisent', 'Daveta', '12394314', 'Melisent.Daveta@college.harvard.edu', '1']
# ['Demetris', 'Janene', '15971480', 'Demetris.Janene@college.harvard.edu', '4']
# ['Therine', 'Durante', '11377390', 'Therine.Durante@college.harvard.edu', '6']
# ['Lolita', 'Esmaria', '10966939', 'Lolita.Esmaria@college.harvard.edu', '7']
# ['Harmonia', 'Mike', '18002861', 'Harmonia.Mike@college.harvard.edu', '8']
# ['Mallory', 'Bandeen', '16165052', 'Mallory.Bandeen@college.harvard.edu', '4']
# ['Alameda', 'Pozzy', '11272947', 'Alameda.Pozzy@college.harvard.edu', '6']
# ['Wanda', 'Primalia', '10595043', 'Wanda.Primalia@college.harvard.edu', '9']
# ['Jany', 'Yuille', '14300562', 'Jany.Yuille@college.harvard.edu', '10']
# ['Shandie', 'Kaete', '12267475', 'Shandie.Kaete@college.harvard.edu', '10']
# ['Shandie', 'Kronfeld', '16293724', 'Shandie.Kronfeld@college.harvard.edu', '6']
# ['Adriana', 'Joni', '13722087', 'Adriana.Joni@college.harvard.edu', '8']
# ['Jany', 'Chick', '16714167', 'Jany.Chick@college.harvard.edu', '7']
# ['Shaylyn', 'Dermott', '15790783', 'Shaylyn.Dermott@college.harvard.edu', '10']
# ['Nannie', 'Kamaria', '12036948', 'Nannie.Kamaria@college.harvard.edu', '6']
# ['Hyacinthe', 'Ardeha', '10077366', 'Hyacinthe.Ardeha@college.harvard.edu', '2']
# ['Rhea', 'Honoria', '14749518', 'Rhea.Honoria@college.harvard.edu', '11']
# ['Bertine', 'Viddah', '15471520', 'Bertine.Viddah@college.harvard.edu', '5']
# ['Tersina', 'Maisey', '18234618', 'Tersina.Maisey@college.harvard.edu', '6']
# ['Farrah', 'Kronfeld', '13465275', 'Farrah.Kronfeld@college.harvard.edu', '9']
# ['Mady', 'Ferrell', '13518774', 'Mady.Ferrell@college.harvard.edu', '5']
# ['Tracey', 'Bennie', '15049751', 'Tracey.Bennie@college.harvard.edu', '11']
# ['Atlanta', 'Mauer', '12565564', 'Atlanta.Mauer@college.harvard.edu', '11']
# ['Ricky', 'Beebe', '10279094', 'Ricky.Beebe@college.harvard.edu', '8']
# ['Minne', 'Melan', '18978146', 'Minne.Melan@college.harvard.edu', '8']
# ['Kayla', 'Kaete', '11745772', 'Kayla.Kaete@college.harvard.edu', '1']
# ['Ashlee', 'Rurik', '15452212', 'Ashlee.Rurik@college.harvard.edu', '11']
# ['Vanessa', 'Ardra', '15201110', 'Vanessa.Ardra@college.harvard.edu', '5']
# ['Shauna', 'Nedrud', '17787736', 'Shauna.Nedrud@college.harvard.edu', '7']
# ['Merry', 'Meli', '19293136', 'Merry.Meli@college.harvard.edu', '6']
# ['Vanessa', 'Baptlsta', '17907239', 'Vanessa.Baptlsta@college.harvard.edu', '7']
# ['Brana', 'Tacye', '19181978', 'Brana.Tacye@college.harvard.edu', '10']
# ['Esmeralda', 'Nikaniki', '16722854', 'Esmeralda.Nikaniki@college.harvard.edu', '6']
# ['Ann-Marie', 'Sherfield', '12584791', 'Ann-Marie.Sherfield@college.harvard.edu', '2']
# ['Mara', 'Alva', '19709563', 'Mara.Alva@college.harvard.edu', '3']
# ['Johna', 'Gunn', '14787982', 'Johna.Gunn@college.harvard.edu', '6']
# ['Charlena', 'Redmond', '10221543', 'Charlena.Redmond@college.harvard.edu', '2']
# ['Jerry', 'Naor', '11001071', 'Jerry.Naor@college.harvard.edu', '3']
# ['Tarra', 'Hessler', '14325727', 'Tarra.Hessler@college.harvard.edu', '10']
# ['Karina', 'Demitria', '13558041', 'Karina.Demitria@college.harvard.edu', '3']
# ['Laure', 'Shama', '16817632', 'Laure.Shama@college.harvard.edu', '3']
# ['Emylee', 'Felecia', '19931607', 'Emylee.Felecia@college.harvard.edu', '10']
# ['Allyce', 'Melony', '14607204', 'Allyce.Melony@college.harvard.edu', '10']
# ['Chloris', 'Seumas', '15887530', 'Chloris.Seumas@college.harvard.edu', '1']
# ['Dede', 'Reinke', '16737716', 'Dede.Reinke@college.harvard.edu', '0']
# ['Harmonia', 'Diogenes', '14499510', 'Harmonia.Diogenes@college.harvard.edu', '6']
# ['Benita', 'Zola', '18055753', 'Benita.Zola@college.harvard.edu', '0']
# ['Florencia', 'Marlie', '11345702', 'Florencia.Marlie@college.harvard.edu', '0']
# ['Darlleen', 'Reidar', '19734836', 'Darlleen.Reidar@college.harvard.edu', '0']
# ['Aeriela', 'Lanita', '12740103', 'Aeriela.Lanita@college.harvard.edu', '7']
# ['Lita', 'Jalbert', '16737782', 'Lita.Jalbert@college.harvard.edu', '4']
# ['Esmeralda', 'Swanhildas', '18090887', 'Esmeralda.Swanhildas@college.harvard.edu', '0']
# ['Vivia', 'Marden', '17397965', 'Vivia.Marden@college.harvard.edu', '2']
# ['Lorenza', 'Koehler', '18869543', 'Lorenza.Koehler@college.harvard.edu', '7']
# ['Valli', 'Lattie', '16073877', 'Valli.Lattie@college.harvard.edu', '10']
# ['Renie', 'Pettiford', '11890478', 'Renie.Pettiford@college.harvard.edu', '5']
# ['Flory', 'Raama', '12275983', 'Flory.Raama@college.harvard.edu', '2']
# ['Vanessa', 'Ogren', '10174272', 'Vanessa.Ogren@college.harvard.edu', '4']
# ['Shaine', 'Meli', '15484522', 'Shaine.Meli@college.harvard.edu', '1']
# ['Ilse', 'Zetta', '13378562', 'Ilse.Zetta@college.harvard.edu', '5']
# ['Kathi', 'Urania', '12496538', 'Kathi.Urania@college.harvard.edu', '0']
# ['Aigneis', 'Bartlett', '18616245', 'Aigneis.Bartlett@college.harvard.edu', '7']
# ['Dede', 'Vanni', '11772048', 'Dede.Vanni@college.harvard.edu', '5']
# ['Karina', 'Septima', '10705116', 'Karina.Septima@college.harvard.edu', '3']
# ['Lenna', 'Gillan', '16279900', 'Lenna.Gillan@college.harvard.edu', '1']
# ['Tatiania', 'Jacobah', '11556886', 'Tatiania.Jacobah@college.harvard.edu', '9']
# ['Kimmy', 'Erb', '16700176', 'Kimmy.Erb@college.harvard.edu', '1']
# ['Allyce', 'Kathie', '17267839', 'Allyce.Kathie@college.harvard.edu', '9']
# ['Dorice', 'Emmaline', '10494020', 'Dorice.Emmaline@college.harvard.edu', '0']
# ['Latisha', 'Aaberg', '14259647', 'Latisha.Aaberg@college.harvard.edu', '1']
# ['Odessa', 'Fredi', '18714567', 'Odessa.Fredi@college.harvard.edu', '3']
# ['Tamqrah', 'Melan', '13452539', 'Tamqrah.Melan@college.harvard.edu', '4']
# ['Nelle', 'Behre', '16448122', 'Nelle.Behre@college.harvard.edu', '10']
# ['Daphne', 'Eliathas', '13658434', 'Daphne.Eliathas@college.harvard.edu', '6']
# ['Sharlene', 'Carolin', '12191886', 'Sharlene.Carolin@college.harvard.edu', '8']
# ['Kaja', 'Carbo', '10160444', 'Kaja.Carbo@college.harvard.edu', '3']
# ['Agathe', 'Janith', '15193473', 'Agathe.Janith@college.harvard.edu', '9']
# ['Jennica', 'Carleen', '14124106', 'Jennica.Carleen@college.harvard.edu', '9']
# ['Lolita', 'Rheingold', '12345849', 'Lolita.Rheingold@college.harvard.edu', '4']
# ['Xylina', 'Even', '13230029', 'Xylina.Even@college.harvard.edu', '3']
# ['Corina', 'Khorma', '18801221', 'Corina.Khorma@college.harvard.edu', '11']
# ['Lucille', 'Jalbert', '17029227', 'Lucille.Jalbert@college.harvard.edu', '9']
# ['Desirae', 'Schenck', '10687802', 'Desirae.Schenck@college.harvard.edu', '2']
# ['Clarice', 'Constancy', '18401177', 'Clarice.Constancy@college.harvard.edu', '3']
# ['Kalina', 'Byrne', '16172206', 'Kalina.Byrne@college.harvard.edu', '8']
# ['Ottilie', 'Jarib', '13711019', 'Ottilie.Jarib@college.harvard.edu', '5']
# ['Millie', 'Tound', '10802903', 'Millie.Tound@college.harvard.edu', '0']
# ['Molli', 'Orpah', '15713449', 'Molli.Orpah@college.harvard.edu', '7']
# ['Aeriela', 'Tannie', '13806999', 'Aeriela.Tannie@college.harvard.edu', '7']
# ['Meg', 'Alice', '16445431', 'Meg.Alice@college.harvard.edu', '1']
# ['Elka', 'Sikorski', '17302491', 'Elka.Sikorski@college.harvard.edu', '11']
# ['Darlleen', 'Alcott', '19099571', 'Darlleen.Alcott@college.harvard.edu', '11']
# ['Shauna', 'Dunkin', '17752080', 'Shauna.Dunkin@college.harvard.edu', '8']
# ['Sadie', 'Morgun', '14448844', 'Sadie.Morgun@college.harvard.edu', '10']
# ['Celestyna', 'Bennie', '18135448', 'Celestyna.Bennie@college.harvard.edu', '8']
# ['June', 'Nisbet', '14808539', 'June.Nisbet@college.harvard.edu', '0']
# ['Kelly', 'Larochelle', '13560035', 'Kelly.Larochelle@college.harvard.edu', '0']
# ['Kerrin', 'Merat', '12449723', 'Kerrin.Merat@college.harvard.edu', '7']
# ['Sherrie', 'Brenn', '18386637', 'Sherrie.Brenn@college.harvard.edu', '7']
# ['Dulce', 'Hoban', '16394788', 'Dulce.Hoban@college.harvard.edu', '5']
# ['Marti', 'Garlinda', '14768316', 'Marti.Garlinda@college.harvard.edu', '8']
# ['Amelia', 'Westphal', '18233684', 'Amelia.Westphal@college.harvard.edu', '1']
# ['Sarette', 'Albertine', '14845125', 'Sarette.Albertine@college.harvard.edu', '7']
# ['Cindelyn', 'Holbrook', '12951408', 'Cindelyn.Holbrook@college.harvard.edu', '2']
# ['Ginnie', 'Shelba', '17277163', 'Ginnie.Shelba@college.harvard.edu', '10']
# ['Susan', 'Vittoria', '13986225', 'Susan.Vittoria@college.harvard.edu', '3']
# ['Sissy', 'Anestassia', '10159636', 'Sissy.Anestassia@college.harvard.edu', '8']
# ['Cassandra', 'Durante', '19700216', 'Cassandra.Durante@college.harvard.edu', '5']
# ['Cathie', 'Stover', '10070624', 'Cathie.Stover@college.harvard.edu', '8']
# ['Charissa', 'Celestine', '19960389', 'Charissa.Celestine@college.harvard.edu', '4']
# ['Fred', 'Malina', '11351426', 'Fred.Malina@college.harvard.edu', '4']
# ['Marita', 'Linehan', '19612251', 'Marita.Linehan@college.harvard.edu', '10']
# ['Lorenza', 'Zenas', '15456782', 'Lorenza.Zenas@college.harvard.edu', '4']
# ['Drucie', 'Karylin', '18703631', 'Drucie.Karylin@college.harvard.edu', '8']
# ['Nerta', 'Modie', '11532864', 'Nerta.Modie@college.harvard.edu', '4']
# ['Claudina', 'Durware', '18346597', 'Claudina.Durware@college.harvard.edu', '3']
# ['Andree', 'Roche', '19632846', 'Andree.Roche@college.harvard.edu', '10']
# ['Nadine', 'Kosey', '17956930', 'Nadine.Kosey@college.harvard.edu', '3']
# ['Laure', 'Oscar', '12525371', 'Laure.Oscar@college.harvard.edu', '7']
# ['Tierney', 'Wu', '19390579', 'Tierney.Wu@college.harvard.edu', '6']
# ['Dari', 'Paton', '15473564', 'Dari.Paton@college.harvard.edu', '10']
# ['Viviene', 'Peg', '12383317', 'Viviene.Peg@college.harvard.edu', '4']
# ['Emma', 'Braun', '16996166', 'Emma.Braun@college.harvard.edu', '9']
# ['Mathilda', 'Henrie', '12978721', 'Mathilda.Henrie@college.harvard.edu', '1']
# ['Romona', 'Merna', '15036450', 'Romona.Merna@college.harvard.edu', '4']
# ['Jere', 'Toffic', '11539889', 'Jere.Toffic@college.harvard.edu', '4']
# ['Marinna', 'Parette', '16140510', 'Marinna.Parette@college.harvard.edu', '7']
# ['Ketti', 'Tiffa', '15469152', 'Ketti.Tiffa@college.harvard.edu', '7']
# ['Harmonia', 'Carri', '12627315', 'Harmonia.Carri@college.harvard.edu', '9']
# ...
# ['Ellette', 'Skurnik', '17920533', 'Ellette.Skurnik@college.harvard.edu', '10']
# ['Ginnie', 'Gunn', '15626505', 'Ginnie.Gunn@college.harvard.edu', '1']
# ['Thalia', 'Manolo', '12596752', 'Thalia.Manolo@college.harvard.edu', '5']
# ['Alie', 'Tybald', '14250354', 'Alie.Tybald@college.harvard.edu', '3']
# ['Dawn', 'Stilwell', '17553201', 'Dawn.Stilwell@college.harvard.edu', '7']
# ['Kirstin', 'Johanna', '18037145', 'Kirstin.Johanna@college.harvard.edu', '5']
# ['Nyssa', 'Longfellow', '16028266', 'Nyssa.Longfellow@college.harvard.edu', '0']
# ['Basia', 'Elsinore', '15094239', 'Basia.Elsinore@college.harvard.edu', '1']
# ['Allis', 'Halsey', '15226344', 'Allis.Halsey@college.harvard.edu', '5']
# ['Merry', 'Drus', '12392296', 'Merry.Drus@college.harvard.edu', '4']
# ['Leanna', 'Terencio', '10279646', 'Leanna.Terencio@college.harvard.edu', '9']
# ['Claresta', 'Adlare', '19932243', 'Claresta.Adlare@college.harvard.edu', '10']
# ['Cherilyn', 'Egbert', '11969863', 'Cherilyn.Egbert@college.harvard.edu', '10']
# ['Anestassia', 'Claudine', '11114570', 'Anestassia.Claudine@college.harvard.edu', '8']
# ['Kittie', 'Taima', '12266700', 'Kittie.Taima@college.harvard.edu', '8']
# ['Demetris', 'Bertold', '17777816', 'Demetris.Bertold@college.harvard.edu', '1']
# ['Zondra', 'Shaddock', '10782217', 'Zondra.Shaddock@college.harvard.edu', '7']
# ['Marti', 'Maisey', '17171855', 'Marti.Maisey@college.harvard.edu', '11']
# ['Bee', 'Mallon', '13634956', 'Bee.Mallon@college.harvard.edu', '4']
# ['Dawn', 'Kunin', '12977263', 'Dawn.Kunin@college.harvard.edu', '4']
# ['Emmey', 'Rona', '15608509', 'Emmey.Rona@college.harvard.edu', '2']
# ['Ida', 'Wilkinson', '17300062', 'Ida.Wilkinson@college.harvard.edu', '2']
# ['Dorene', 'Solitta', '16469142', 'Dorene.Solitta@college.harvard.edu', '10']
# ['Audrie', 'Baptlsta', '14111226', 'Audrie.Baptlsta@college.harvard.edu', '5']
# ['Drucie', 'Abram', '15790582', 'Drucie.Abram@college.harvard.edu', '6']
# ['Hollie', 'Teryn', '19937443', 'Hollie.Teryn@college.harvard.edu', '3']
# ['Evaleen', 'Ashely', '15240424', 'Evaleen.Ashely@college.harvard.edu', '7']
# ['Justinn', 'Papageno', '13205422', 'Justinn.Papageno@college.harvard.edu', '7']
# ['Elbertina', 'Pattin', '10850180', 'Elbertina.Pattin@college.harvard.edu', '0']
# ['Abbie', 'Mich', '11327673', 'Abbie.Mich@college.harvard.edu', '1']
# ['Alia', 'Audly', '11579133', 'Alia.Audly@college.harvard.edu', '10']
# ['Mara', 'Clarissa', '16264437', 'Mara.Clarissa@college.harvard.edu', '1']
# ['Aaren', 'Torray', '12031783', 'Aaren.Torray@college.harvard.edu', '2']
# ['Loree', 'Ingra', '18682611', 'Loree.Ingra@college.harvard.edu', '7']
# ['Ursulina', 'Charmine', '17843792', 'Ursulina.Charmine@college.harvard.edu', '7']
# ['Iseabal', 'Land', '15815392', 'Iseabal.Land@college.harvard.edu', '9']
# ['Aryn', 'Yerkovich', '14900582', 'Aryn.Yerkovich@college.harvard.edu', '2']
# ['Allyce', 'Rozanna', '14944069', 'Allyce.Rozanna@college.harvard.edu', '0']
# ['Konstance', 'Talia', '18555352', 'Konstance.Talia@college.harvard.edu', '6']
# ['Brietta', 'Allina', '19861051', 'Brietta.Allina@college.harvard.edu', '9']
# ['Talya', 'Heisel', '15024268', 'Talya.Heisel@college.harvard.edu', '0']
# ['Ketti', 'Cohdwell', '19190297', 'Ketti.Cohdwell@college.harvard.edu', '10']
# ['Malina', 'Bonilla', '10078311', 'Malina.Bonilla@college.harvard.edu', '10']
# ['Thalia', 'McLaughlin', '12937283', 'Thalia.McLaughlin@college.harvard.edu', '6']
# ['Ardeen', 'Nedrud', '11702187', 'Ardeen.Nedrud@college.harvard.edu', '5']
# ['Clary', 'Merat', '11186850', 'Clary.Merat@college.harvard.edu', '2']
# ['Wilma', 'Justinn', '10037489', 'Wilma.Justinn@college.harvard.edu', '1']
# ['Clarice', 'Philoo', '14558528', 'Clarice.Philoo@college.harvard.edu', '10']
# ['Fayre', 'Erich', '15748763', 'Fayre.Erich@college.harvard.edu', '11']
# ['Jan', 'Elsinore', '18874845', 'Jan.Elsinore@college.harvard.edu', '8']
# ['Maisey', 'Torray', '15268100', 'Maisey.Torray@college.harvard.edu', '10']
# ['Priscilla', 'Atcliffe', '10738212', 'Priscilla.Atcliffe@college.harvard.edu', '7']
# ['Fredericka', 'Clara', '15308749', 'Fredericka.Clara@college.harvard.edu', '2']
# ['Myrtice', 'Standing', '19608294', 'Myrtice.Standing@college.harvard.edu', '7']
# ['Pearline', 'Kaja', '14368835', 'Pearline.Kaja@college.harvard.edu', '3']
# ['Natka', 'Ellord', '13481438', 'Natka.Ellord@college.harvard.edu', '9']
# ['Larine', 'Wolfgram', '13603911', 'Larine.Wolfgram@college.harvard.edu', '10']
# ['Juliane', 'Eldrid', '15647241', 'Juliane.Eldrid@college.harvard.edu', '1']
# ['Nannie', 'Doig', '11796401', 'Nannie.Doig@college.harvard.edu', '4']
# ['Ursulina', 'Belanger', '18234916', 'Ursulina.Belanger@college.harvard.edu', '5']
# ['Kamilah', 'Dex', '17490516', 'Kamilah.Dex@college.harvard.edu', '6']
# ['Rebeca', 'Cullin', '14775995', 'Rebeca.Cullin@college.harvard.edu', '11']
# ['Charlena', 'Curren', '14208326', 'Charlena.Curren@college.harvard.edu', '4']
# ['Maurene', 'Reneta', '15341215', 'Maurene.Reneta@college.harvard.edu', '9']
# ['Adore', 'Ferrell', '14330046', 'Adore.Ferrell@college.harvard.edu', '0']
# ['Celene', 'Flita', '14264948', 'Celene.Flita@college.harvard.edu', '8']
# ['Sara-Ann', 'Granoff', '15624180', 'Sara-Ann.Granoff@college.harvard.edu', '2']
# ['Alejandra', 'Goldina', '14849367', 'Alejandra.Goldina@college.harvard.edu', '2']
# ['Barbara', 'Izaak', '11720047', 'Barbara.Izaak@college.harvard.edu', '2']
# ['Dagmar', 'Ralfston', '12534837', 'Dagmar.Ralfston@college.harvard.edu', '11']
# ['Bobinette', 'Gale', '16366790', 'Bobinette.Gale@college.harvard.edu', '6']
# ['Deirdre', 'Chrystel', '18986651', 'Deirdre.Chrystel@college.harvard.edu', '3']
# ['Joane', 'Clarissa', '14867505', 'Joane.Clarissa@college.harvard.edu', '1']
# ['Luci', 'Hartnett', '14353282', 'Luci.Hartnett@college.harvard.edu', '10']
# ['Tybie', 'Elo', '19894264', 'Tybie.Elo@college.harvard.edu', '4']
# ['Farrah', 'Ariella', '18022796', 'Farrah.Ariella@college.harvard.edu', '1']
# ['Rivalee', 'Dom', '18569603', 'Rivalee.Dom@college.harvard.edu', '5']
# ['Etta', 'Darbie', '10556917', 'Etta.Darbie@college.harvard.edu', '10']
# ['Aeriela', 'Colbert', '16741827', 'Aeriela.Colbert@college.harvard.edu', '1']
# ['Brooks', 'Korey', '11114508', 'Brooks.Korey@college.harvard.edu', '4']
# ['Pollyanna', 'Paton', '15252559', 'Pollyanna.Paton@college.harvard.edu', '3']
# ['Emelina', 'Hachmin', '18917186', 'Emelina.Hachmin@college.harvard.edu', '11']
# ['Lelah', 'Raychel', '13536372', 'Lelah.Raychel@college.harvard.edu', '1']
# ['Joy', 'Dielu', '16119039', 'Joy.Dielu@college.harvard.edu', '6']
# ['Britni', 'Tybald', '10439068', 'Britni.Tybald@college.harvard.edu', '11']
# ['Gerrie', 'Morrill', '14919551', 'Gerrie.Morrill@college.harvard.edu', '8']
# ['Kayla', 'Hachmin', '10673577', 'Kayla.Hachmin@college.harvard.edu', '11']
# ['Aurore', 'Martsen', '18671855', 'Aurore.Martsen@college.harvard.edu', '1']
# ['Miquela', 'Keelia', '13632942', 'Miquela.Keelia@college.harvard.edu', '6']
# ['Talya', 'Lynn', '15487456', 'Talya.Lynn@college.harvard.edu', '8']
# ['Mallory', 'Ajay', '11476841', 'Mallory.Ajay@college.harvard.edu', '10']
# ['Nariko', 'Marsden', '11707944', 'Nariko.Marsden@college.harvard.edu', '9']
# ['Quintina', 'Ralfston', '10073376', 'Quintina.Ralfston@college.harvard.edu', '8']
# ['Fawne', 'Sigfrid', '11903270', 'Fawne.Sigfrid@college.harvard.edu', '2']
# ['Kore', 'Freddi', '19662289', 'Kore.Freddi@college.harvard.edu', '8']
# ['Jan', 'Liva', '16093870', 'Jan.Liva@college.harvard.edu', '2']
# ['Jorry', 'Stilwell', '19574470', 'Jorry.Stilwell@college.harvard.edu', '10']
# ['Ileana', 'Erlandson', '17180867', 'Ileana.Erlandson@college.harvard.edu', '10']
# ['Marti', 'Orpah', '12030548', 'Marti.Orpah@college.harvard.edu', '1']
# ['Nelle', 'Erich', '13451313', 'Nelle.Erich@college.harvard.edu', '3']
# ['Carly', 'Danby', '19758688', 'Carly.Danby@college.harvard.edu', '10']
# ['Ileana', 'Eno', '15411773', 'Ileana.Eno@college.harvard.edu', '1']
# ['Tobe', 'Luhe', '19471335', 'Tobe.Luhe@college.harvard.edu', '5']
# ['Goldie', 'Sisile', '14414869', 'Goldie.Sisile@college.harvard.edu', '3']
# ['Allis', 'Couture', '18620374', 'Allis.Couture@college.harvard.edu', '5']
# ['Rhoda', 'Gale', '14088915', 'Rhoda.Gale@college.harvard.edu', '7']
# ['Kristan', 'Newell', '19604869', 'Kristan.Newell@college.harvard.edu', '2']
# ['Lynde', 'Olympium', '11052779', 'Lynde.Olympium@college.harvard.edu', '10']
# ['Chandra', 'Garlinda', '16932813', 'Chandra.Garlinda@college.harvard.edu', '9']
# ['Lila', 'Sinegold', '19159524', 'Lila.Sinegold@college.harvard.edu', '8']
# ['Frank', 'Kathie', '16862194', 'Frank.Kathie@college.harvard.edu', '7']
# ['Paulita', 'Ogren', '13497189', 'Paulita.Ogren@college.harvard.edu', '6']
# ['Clarice', 'Joli', '12851512', 'Clarice.Joli@college.harvard.edu', '6']
# ['Concettina', 'Bohlin', '13186776', 'Concettina.Bohlin@college.harvard.edu', '8']
# ['Jasmina', 'Joeann', '17828548', 'Jasmina.Joeann@college.harvard.edu', '0']
# ['Tera', 'McLaughlin', '11154176', 'Tera.McLaughlin@college.harvard.edu', '4']
# ['Lynde', 'Judye', '13912241', 'Lynde.Judye@college.harvard.edu', '4']
# ['Ingrid', 'Eachern', '12490247', 'Ingrid.Eachern@college.harvard.edu', '9']
# ['Melanie', 'Chinua', '14492121', 'Melanie.Chinua@college.harvard.edu', '10']
# ['Myriam', 'Cordi', '15070777', 'Myriam.Cordi@college.harvard.edu', '10']
# ['Karolina', 'Suzetta', '16865470', 'Karolina.Suzetta@college.harvard.edu', '4']
# ['Betta', 'Wallis', '13059662', 'Betta.Wallis@college.harvard.edu', '3']
# ['Paulita', 'Felizio', '12402678', 'Paulita.Felizio@college.harvard.edu', '3']
# ['Leeanne', 'Monaco', '17596570', 'Leeanne.Monaco@college.harvard.edu', '8']
# ['Latisha', 'Verger', '19686138', 'Latisha.Verger@college.harvard.edu', '2']
# ['Aryn', 'Crudden', '18626775', 'Aryn.Crudden@college.harvard.edu', '1']
# ['Cathie', 'Bettine', '12998855', 'Cathie.Bettine@college.harvard.edu', '4']
# ['Tilly', 'Raffo', '14504872', 'Tilly.Raffo@college.harvard.edu', '9']
# ['Robinia', 'Larochelle', '16935466', 'Robinia.Larochelle@college.harvard.edu', '8']
# ['Teriann', 'Raseda', '13881261', 'Teriann.Raseda@college.harvard.edu', '5']
# ['Etta', 'Girardo', '13042891', 'Etta.Girardo@college.harvard.edu', '4']
# ['Danika', 'Nunci', '19294671', 'Danika.Nunci@college.harvard.edu', '9']
# ['Elora', 'Haerr', '11676178', 'Elora.Haerr@college.harvard.edu', '2']
# ['Sheelagh', 'Adamsen', '18459894', 'Sheelagh.Adamsen@college.harvard.edu', '11']
# ['Britte', 'Baudin', '10787024', 'Britte.Baudin@college.harvard.edu', '11']
# ['Justinn', 'Shaddock', '11087272', 'Justinn.Shaddock@college.harvard.edu', '0']
# ['Suzette', 'Etom', '18230466', 'Suzette.Etom@college.harvard.edu', '4']
# ['Fina', 'Hoban', '19667123', 'Fina.Hoban@college.harvard.edu', '0']
# ['Noelle', 'Mozelle', '12677312', 'Noelle.Mozelle@college.harvard.edu', '2']
# ['Jsandye', 'Raseda', '10487563', 'Jsandye.Raseda@college.harvard.edu', '1']
# ['Courtnay', 'Johnsson', '19747366', 'Courtnay.Johnsson@college.harvard.edu', '11']
# ['Lanna', 'Kaja', '10324447', 'Lanna.Kaja@college.harvard.edu', '6']
# ['Margette', 'Boehike', '17049726', 'Margette.Boehike@college.harvard.edu', '7']
# ['Phylis', 'Koehler', '16551520', 'Phylis.Koehler@college.harvard.edu', '2']
# ['Gretal', 'Carvey', '12341371', 'Gretal.Carvey@college.harvard.edu', '3']
# ['Latisha', 'Even', '18843429', 'Latisha.Even@college.harvard.edu', '7']
# ['Althea', 'Deegan', '12802873', 'Althea.Deegan@college.harvard.edu', '4']
# ['Fanny', 'Peg', '12661749', 'Fanny.Peg@college.harvard.edu', '7']
# ['Arabel', 'Dalli', '18867335', 'Arabel.Dalli@college.harvard.edu', '0']
# ['Sallie', 'Tjon', '17702318', 'Sallie.Tjon@college.harvard.edu', '5']
# ['Elyssa', 'Zuzana', '16973517', 'Elyssa.Zuzana@college.harvard.edu', '6']
# ['Luci', 'Myrilla', '18165262', 'Luci.Myrilla@college.harvard.edu', '6']
# ['Ketti', 'Yorick', '14552309', 'Ketti.Yorick@college.harvard.edu', '1']
# ['Julieta', 'Remmer', '10462950', 'Julieta.Remmer@college.harvard.edu', '8']
# ['Mathilda', 'Japeth', '19845330', 'Mathilda.Japeth@college.harvard.edu', '7']
# ['Liana', 'Redmond', '12845395', 'Liana.Redmond@college.harvard.edu', '7']
# ['Regina', 'Rodmann', '17836189', 'Regina.Rodmann@college.harvard.edu', '7']
# ['Ariela', 'Robertson', '14099607', 'Ariela.Robertson@college.harvard.edu', '10']
# ['Elise', 'Adalbert', '13637858', 'Elise.Adalbert@college.harvard.edu', '4']
# ['Talya', 'Ciapas', '10195951', 'Talya.Ciapas@college.harvard.edu', '1']
# ['Merrie', 'Ivens', '17807279', 'Merrie.Ivens@college.harvard.edu', '2']
# ['Elise', 'Kellby', '12101108', 'Elise.Kellby@college.harvard.edu', '5']
# ['Ekaterina', 'Donoghue', '10558401', 'Ekaterina.Donoghue@college.harvard.edu', '1']
# ['Annecorinne', 'Cecile', '13506041', 'Annecorinne.Cecile@college.harvard.edu', '1']
# ['Joelly', 'Isacco', '15612284', 'Joelly.Isacco@college.harvard.edu', '1']
# ['Jobi', 'Creamer', '18169826', 'Jobi.Creamer@college.harvard.edu', '2']
# ['Genovera', 'Alexandr', '13576426', 'Genovera.Alexandr@college.harvard.edu', '9']
# ['Dolli', 'Euridice', '14268919', 'Dolli.Euridice@college.harvard.edu', '1']
# ['Elka', 'Haldas', '10629376', 'Elka.Haldas@college.harvard.edu', '0']
# ['Shell', 'Phaidra', '13136613', 'Shell.Phaidra@college.harvard.edu', '5']
# ['Liana', 'Lissi', '13911474', 'Liana.Lissi@college.harvard.edu', '6']
# ['Robinia', 'Ellord', '10742371', 'Robinia.Ellord@college.harvard.edu', '8']
# ['Adelle', 'Nea', '13071744', 'Adelle.Nea@college.harvard.edu', '4']
# ['Sidoney', 'Etom', '11008621', 'Sidoney.Etom@college.harvard.edu', '3']
# ['Marguerite', 'Ardeha', '19849461', 'Marguerite.Ardeha@college.harvard.edu', '5']
# ['Tina', 'Isidore', '10302738', 'Tina.Isidore@college.harvard.edu', '6']
# ['Nikki', 'Bobbee', '16133910', 'Nikki.Bobbee@college.harvard.edu', '10']
# ['Monika', 'Gilbertson', '17032612', 'Monika.Gilbertson@college.harvard.edu', '3']
# ['Desirae', 'Sholley', '19475426', 'Desirae.Sholley@college.harvard.edu', '3']
# ['Bertine', 'Avi', '15189854', 'Bertine.Avi@college.harvard.edu', '7']
# ['Charissa', 'Garrison', '10164177', 'Charissa.Garrison@college.harvard.edu', '3']
# ['Ayn', 'Yuille', '14836415', 'Ayn.Yuille@college.harvard.edu', '3']
# ['Heida', 'Colleen', '11451119', 'Heida.Colleen@college.harvard.edu', '1']
# ['Kary', 'Hurley', '19259148', 'Kary.Hurley@college.harvard.edu', '4']
# ['Nita', 'Engdahl', '12930901', 'Nita.Engdahl@college.harvard.edu', '11']
# ['Catrina', 'Adlare', '14406501', 'Catrina.Adlare@college.harvard.edu', '7']
# ['Nicoli', 'Sholley', '17218018', 'Nicoli.Sholley@college.harvard.edu', '8']
# ['Jacquetta', 'McAdams', '11054765', 'Jacquetta.McAdams@college.harvard.edu', '2']
# ['Anica', 'Redmond', '16156205', 'Anica.Redmond@college.harvard.edu', '3']
# ['Cathyleen', 'Sholley', '16958010', 'Cathyleen.Sholley@college.harvard.edu', '6']
# ['Lonnie', 'Blisse', '14330413', 'Lonnie.Blisse@college.harvard.edu', '6']
# ['Imojean', 'Rad', '13287914', 'Imojean.Rad@college.harvard.edu', '5']
# ['Gaylene', 'Chandler', '12192844', 'Gaylene.Chandler@college.harvard.edu', '10']
# ['Dyann', 'Martguerita', '11819882', 'Dyann.Martguerita@college.harvard.edu', '1']
# ['Renae', 'Wittie', '14464888', 'Renae.Wittie@college.harvard.edu', '9']
# ['Viki', 'Lucienne', '11379809', 'Viki.Lucienne@college.harvard.edu', '0']
# ['Atlanta', 'Ax', '12834470', 'Atlanta.Ax@college.harvard.edu', '3']
# ['Angelique', 'Briney', '14065940', 'Angelique.Briney@college.harvard.edu', '9']
# ['Jeanna', 'Gordon', '18251154', 'Jeanna.Gordon@college.harvard.edu', '3']
# ['Lynea', 'Israeli', '17410167', 'Lynea.Israeli@college.harvard.edu', '0']
# ['Judy', 'Merell', '10991251', 'Judy.Merell@college.harvard.edu', '0']
# ['Jillayne', 'Gillan', '13366343', 'Jillayne.Gillan@college.harvard.edu', '3']
# ['Vevay', 'Timon', '13203250', 'Vevay.Timon@college.harvard.edu', '6']
# ['Orsola', 'Genna', '17089264', 'Orsola.Genna@college.harvard.edu', '4']
# ['Kalina', 'Carlson', '19727831', 'Kalina.Carlson@college.harvard.edu', '8']
# ['Millie', 'Reidar', '17097091', 'Millie.Reidar@college.harvard.edu', '0']
# ['Kate', 'Selway', '11613307', 'Kate.Selway@college.harvard.edu', '4']
# ['Marsiella', 'Edmund', '17939908', 'Marsiella.Edmund@college.harvard.edu', '9']
# ['Gretal', 'Muriel', '17593926', 'Gretal.Muriel@college.harvard.edu', '2']
# ['Gilda', 'Brieta', '11581271', 'Gilda.Brieta@college.harvard.edu', '9']
# ['Deane', 'Faria', '18144500', 'Deane.Faria@college.harvard.edu', '1']

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Task #2 - generate a file for a house on demand
#
# OK, you've helped the college out with the lottery but now the house administrators are struggling a bit because they have all 2000 students in one file but only care about the students that were assigned to their particular house. Write a small programm that solves that task on demand and generates a csv for them with only their students. You can write a program that does this task on demand for a given house, or you can generate a csv for each house in advance.

# %%
# your code here
import csv

with open("data/students.csv", "r") as file:
    reader = csv.reader(file)
    header = next(reader)  # This will read the first row as the header
    data = [row for row in reader]  # This will read the rest of the rows

print("Header:", header)
print("Data:", data)
# Out:
# Header: ['Oona', 'Swigart', '16076420', 'Oona.Swigart@college.harvard.edu']
# Data: [['Hope', 'Quent', '16435294', 'Hope.Quent@college.harvard.edu'], ['Fayre', 'Vorster', '11185066', 'Fayre.Vorster@college.harvard.edu'], ['Priscilla', 'Geffner', '14666772', 'Priscilla.Geffner@college.harvard.edu'], ['Madeleine', 'Stilwell', '13502774', 'Madeleine.Stilwell@college.harvard.edu'], ['Deirdre', 'Khorma', '11100518', 'Deirdre.Khorma@college.harvard.edu'], ['Anthia', 'Blase', '14657089', 'Anthia.Blase@college.harvard.edu'], ['Diena', 'Shama', '13777228', 'Diena.Shama@college.harvard.edu'], ['Cristabel', 'Audly', '19191289', 'Cristabel.Audly@college.harvard.edu'], ['Misha', 'Tybald', '15474105', 'Misha.Tybald@college.harvard.edu'], ['Carly', 'Haymes', '10825876', 'Carly.Haymes@college.harvard.edu'], ['Chloris', 'Shaddock', '14456015', 'Chloris.Shaddock@college.harvard.edu'], ['Evita', 'Whittaker', '16942112', 'Evita.Whittaker@college.harvard.edu'], ['Fina', 'Zetta', '17941504', 'Fina.Zetta@college.harvard.edu'], ['Carolina', 'Ummersen', '12399079', 'Carolina.Ummersen@college.harvard.edu'], ['Roberta', 'Ingra', '11936833', 'Roberta.Ingra@college.harvard.edu'], ['Moyna', 'Dorothy', '12556187', 'Moyna.Dorothy@college.harvard.edu'], ['Zondra', 'Cadmar', '12486497', 'Zondra.Cadmar@college.harvard.edu'], ['Gusty', 'Merat', '11280490', 'Gusty.Merat@college.harvard.edu'], ['Bertine', 'Merell', '19533403', 'Bertine.Merell@college.harvard.edu'], ['Pierette', 'Hutchison', '16577108', 'Pierette.Hutchison@college.harvard.edu'], ['Sue', 'Oneida', '16223298', 'Sue.Oneida@college.harvard.edu'], ['Gale', 'Hermes', '10553554', 'Gale.Hermes@college.harvard.edu'], ['Inga', 'Bow', '15657083', 'Inga.Bow@college.harvard.edu'], ['Jaclyn', 'Flita', '18705071', 'Jaclyn.Flita@college.harvard.edu'], ['Bernardine', 'Sophronia', '16311101', 'Bernardine.Sophronia@college.harvard.edu'], ['Chrystel', 'Borrell', '16164885', 'Chrystel.Borrell@college.harvard.edu'], ['Larine', 'Paton', '14731172', 'Larine.Paton@college.harvard.edu'], ['Phedra', 'Lia', '11868072', 'Phedra.Lia@college.harvard.edu'], ['Melanie', 'Merna', '17144995', 'Melanie.Merna@college.harvard.edu'], ['Emmey', 'Boehike', '19456940', 'Emmey.Boehike@college.harvard.edu'], ['Alejandra', 'Ehrman', '16185753', 'Alejandra.Ehrman@college.harvard.edu'], ['Yetty', 'Monaco', '14071918', 'Yetty.Monaco@college.harvard.edu'], ['Deirdre', 'Ioab', '11777577', 'Deirdre.Ioab@college.harvard.edu'], ['Catrina', 'Persse', '14686761', 'Catrina.Persse@college.harvard.edu'], ['Heida', 'Izaak', '13942697', 'Heida.Izaak@college.harvard.edu'], ['Sharai', 'Meli', '16097823', 'Sharai.Meli@college.harvard.edu'], ['Aryn', 'Hanleigh', '19408239', 'Aryn.Hanleigh@college.harvard.edu'], ['Melina', 'Elsinore', '13761016', 'Melina.Elsinore@college.harvard.edu'], ['Elyssa', 'Wu', '12316153', 'Elyssa.Wu@college.harvard.edu'], ['Penelopa', 'Harned', '16443115', 'Penelopa.Harned@college.harvard.edu'], ['Rozele', 'Wilkinson', '15118764', 'Rozele.Wilkinson@college.harvard.edu'], ['Melina', 'Jethro', '15840321', 'Melina.Jethro@college.harvard.edu'], ['Jordan', 'Gilmour', '10076614', 'Jordan.Gilmour@college.harvard.edu'], ['Ethel', 'Hartnett', '11383680', 'Ethel.Hartnett@college.harvard.edu'], ['Collen', 'Garek', '17585948', 'Collen.Garek@college.harvard.edu'], ['Jenilee', 'Vastah', '11949445', 'Jenilee.Vastah@college.harvard.edu'], ['Fredericka', 'Lane', '12958619', 'Fredericka.Lane@college.harvard.edu'], ['Asia', 'Demitria', '19103295', 'Asia.Demitria@college.harvard.edu'], ['Ana', 'Scammon', '10701460', 'Ana.Scammon@college.harvard.edu'], ['Wynne', 'Baylor', '12487005', 'Wynne.Baylor@college.harvard.edu'], ['Alexine', 'Ackerley', '14493600', 'Alexine.Ackerley@college.harvard.edu'], ['Fina', 'Himelman', '16919718', 'Fina.Himelman@college.harvard.edu'], ['Beth', 'Roxanna', '13130130', 'Beth.Roxanna@college.harvard.edu'], ['Maud', 'Thema', '19209764', 'Maud.Thema@college.harvard.edu'], ['Myriam', 'Jerold', '11845800', 'Myriam.Jerold@college.harvard.edu'], ['Kaia', 'Cavan', '19395700', 'Kaia.Cavan@college.harvard.edu'], ['M ...

# %%
# on-demand solution

# pick a house
house = 'Adams House'
house_id = house_to_id[house]

file_read = open('data/students_with_house.csv', 'r', )
file_write = open('data/by_house/' + house + ' Students.csv', 'w', newline='')
reader = csv.reader(file_read)
writer = csv.writer(file_write)

# remember that the first row is the header
header = next(reader)  # This will read the first row as the header

# The csv reader maintains a pointer to the current position in the sequence of rows from the CSV file. 
# Initially, this pointer is positioned before the first row. When you call next(reader), 
# it advances this pointer and returns the row at that position.
for row in reader:
    
    # check if house id is the same as selected house
    if int(row[4]) == house_id:
        writer.writerow(row)

file_read.close()
file_write.close()

# %%
# automated solution for all houses

# write a function
def gen_csv(house):
    
    house_id = house_to_id[house]

    file_read = open('data/students_with_house.csv', 'r')
    file_write = open('data/by_house/' + house + ' Students.csv', 'w', newline='')
    reader = csv.reader(file_read)
    writer = csv.writer(file_write)
    header = next(reader) 

    for row in reader:
        if int(row[4]) == house_id:
            writer.writerow(row)

    file_read.close()
    file_write.close()

# %%
# now loop over all houses and call the function for each house
for house in house_to_id:
    gen_csv(house)

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Bonus Tasks
#
# 1. calculate vacant rooms per house
# 2. write a program that computes the number of students assigned per house in a given csv
# 3. write a function that checks whether there are problems with the numbers of students assigned to each house
# 4. write code that assigns students randomly but in such a way that there are no capacity issues.

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# Some house administrators have complaned that the list of students is too long to accomodate all new sophomores assigned to their houses. Since some houses are bigger and others are smaller, we cannot simply generate integers and get away with the randomly generated number of students in each house. Rather, we have to check more carefolly whether there is still capacity. Below, find two useful dictionaries hat should help you to solve this task.

# %%
# bonus is house with exact capacities

house_capacity = {
    'Adams House': 411,
    'Cabot House': 362,
    'Currier House' : 356,
    'Dunster House': 428,
    'Eliot House': 450,
    'Kirkland House': 400,
    'Leverett House': 480,
    'Lowell House': 450,
    'Mather House': 426,
    'Pforzheimer House':360,
    'Quincy House': 420,
    'Winthrop House': 500
}

# number of occupied rooms after seniors have left
house_occupied = {
    'Adams House': 236,
    'Cabot House': 213,
    'Currier House' : 217,
    'Dunster House': 296,
    'Eliot House': 288,
    'Kirkland House': 224,
    'Leverett House': 233,
    'Lowell House': 242,
    'Mather House': 217,
    'Pforzheimer House':195,
    'Quincy House': 253,
    'Winthrop House': 310
}

# %%
house_names = []

for house in house_occupied:
    house_names.append(house)
    
print(house_names)
# Out:
# ['Adams House', 'Cabot House', 'Currier House', 'Dunster House', 'Eliot House', 'Kirkland House', 'Leverett House', 'Lowell House', 'Mather House', 'Pforzheimer House', 'Quincy House', 'Winthrop House']

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>Let's start by writing a small program that helps us to calculate the vacant rooms for each house. Try to use a dictionary structure that contains all information for each house. Feel free to also write a few lines that check how many vacant rooms there are in total.

# %%
vacant_rooms = {}
for house in house_occupied:
    vacant_rooms[house] = house_capacity[house] - house_occupied[house]

print(vacant_rooms)
# Out:
# {'Adams House': 175, 'Cabot House': 149, 'Currier House': 139, 'Dunster House': 132, 'Eliot House': 162, 'Kirkland House': 176, 'Leverett House': 247, 'Lowell House': 208, 'Mather House': 209, 'Pforzheimer House': 165, 'Quincy House': 167, 'Winthrop House': 190}

# %%
# check how many rooms we have in total
total = 0
for rooms in vacant_rooms:
    total +=vacant_rooms[rooms] 
    
print(total)
# Out:
# 2119

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>Let's now write a small function that calculates the number of students assigned per house with our old method and returns a dictionary with that information

# %%
def calculate_students_per_house(filename):

    # helper dict
    helper_dict = {}

    # reader & writer
    file_read = open(filename, "r")

    reader = csv.reader(file_read)
    header = next(reader)  # This will read the first row as the header

    for row in reader:
        house_id = row[4]
        house_name = id_to_house[int(house_id)]
        if(house_name in helper_dict):
            helper_dict[house_name] += 1
        else:
            helper_dict[house_name] = 1

    # close the files
    file_read.close()

    return helper_dict

# %%
print(calculate_students_per_house('data/students_with_house.csv'))
# Out:
# {'Dunster House': 169, 'Quincy House': 150, 'Winthrop House': 165, 'Adams House': 155, 'Eliot House': 194, 'Currier House': 165, 'Mather House': 154, 'Lowell House': 187, 'Cabot House': 171, 'Pforzheimer House': 171, 'Kirkland House': 167, 'Leverett House': 152}

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>Next, let's check by how much we were off for each house with our random approach.

# %%
def house_assignment_check(assignements_per_house):
    
    for house in house_capacity:
        difference =vacant_rooms[house] - assignements_per_house[house]
        
        if difference < 0:
            print(f'There is a problem with {house} - we have assigned {abs(difference)} too many students')
        else:
            print(f'no assignment problems with {house}')

# %%
assigned_students_random = calculate_students_per_house('data/students_with_house.csv')
house_assignment_check(assigned_students_random)
# Out:
# no assignment problems with Adams House
# There is a problem with Cabot House - we have assigned 22 too many students
# There is a problem with Currier House - we have assigned 26 too many students
# There is a problem with Dunster House - we have assigned 37 too many students
# There is a problem with Eliot House - we have assigned 32 too many students
# no assignment problems with Kirkland House
# no assignment problems with Leverett House
# no assignment problems with Lowell House
# no assignment problems with Mather House
# There is a problem with Pforzheimer House - we have assigned 6 too many students
# no assignment problems with Quincy House
# no assignment problems with Winthrop House

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>Finally, let's write a function that assignes houses more carefully. We can still generate random integers to assign a house, but we need to check whether that house still has capacity. For that reason, please create a funcction called assign_house() that you include into the code tat we've written before

# %%
# solution

def assign_house():
    
    house_id = random.randint(0,11)
    house_name = id_to_house[house_id]
    
    
    # check capacity
    if (house_capacity[house_name] - house_occupied[house_name] > 0):
        
        # update occupancy
        house_occupied[house_name] += 1
        print(f'assigned student to{house_name}')
        return house_id
    
    else:
        print(f'no more capacity in {house_name}')
        return assign_house()

# %%
# reader & writer
file_read = open("data/students.csv", "r")
file_write = open('data/students_with_house_correct_capacity.csv', 'w', newline='')

reader = csv.reader(file_read)
writer = csv.writer(file_write)

for row in reader:
    correct_house = assign_house()
    row.append(correct_house)
    writer.writerow(row)

# close the files
file_read.close()
file_write.close()
# Out:
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toMather House
# assigned student toMather House
# assigned student toAdams House
# assigned student toLowell House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toMather House
# assigned student toCabot House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toDunster House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toAdams House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toCurrier House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toCabot House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toMather House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toLeverett House
# assigned student toWinthrop House
# assigned student toCurrier House
# assigned student toCurrier House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toMather House
# assigned student toAdams House
# assigned student toLeverett House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toLeverett House
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toLowell House
# assigned student toMather House
# assigned student toEliot House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toLowell House
# assigned student toMather House
# assigned student toMather House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toEliot House
# assigned student toAdams House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toDunster House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toEliot House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toLowell House
# assigned student toMather House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toCurrier House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toMather House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toCabot House
# assigned student toCabot House
# assigned student toEliot House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toLowell House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toCabot House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toMather House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toLeverett House
# assigned student toCabot House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toCurrier House
# assigned student toLowell House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toMather House
# assigned student toMather House
# assigned student toAdams House
# assigned student toMather House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toEliot House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toMather House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toAdams House
# assigned student toMather House
# assigned student toDunster House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toMather House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toLowell House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toLowell House
# assigned student toDunster House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toPforzheimer House
# assigned student toAdams House
# assigned student toMather House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toMather House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toLowell House
# assigned student toCurrier House
# assigned student toCabot House
# assigned student toMather House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toLowell House
# assigned student toDunster House
# assigned student toLowell House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toMather House
# assigned student toDunster House
# assigned student toMather House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toDunster House
# assigned student toLowell House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toCabot House
# assigned student toEliot House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toWinthrop House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toMather House
# assigned student toCabot House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toAdams House
# assigned student toMather House
# assigned student toMather House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toDunster House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toMather House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toAdams House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toDunster House
# assigned student toMather House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toMather House
# assigned student toCabot House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toMather House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toMather House
# assigned student toAdams House
# assigned student toLowell House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toLeverett House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toLeverett House
# assigned student toCabot House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toLowell House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toLowell House
# assigned student toMather House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toAdams House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toAdams House
# assigned student toDunster House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toMather House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toCabot House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toKirkland House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toCabot House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toKirkland House
# assigned student toCabot House
# assigned student toMather House
# assigned student toCabot House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toCabot House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toLowell House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toLowell House
# assigned student toMather House
# assigned student toEliot House
# assigned student toLeverett House
# assigned student toLowell House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toKirkland House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toKirkland House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toAdams House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toMather House
# assigned student toMather House
# assigned student toEliot House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toWinthrop House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toMather House
# assigned student toEliot House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toLeverett House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toMather House
# assigned student toDunster House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toQuincy House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toAdams House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toCurrier House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toQuincy House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toPforzheimer House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toAdams House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toLeverett House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toDunster House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toLowell House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toMather House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toDunster House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toKirkland House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toCurrier House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toCabot House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toDunster House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toLeverett House
# assigned student toLowell House
# assigned student toMather House
# assigned student toDunster House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toEliot House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toLowell House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toLeverett House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toMather House
# assigned student toCurrier House
# assigned student toLowell House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toQuincy House
# assigned student toLowell House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toPforzheimer House
# assigned student toMather House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toCabot House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toLowell House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toLeverett House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toDunster House
# assigned student toEliot House
# assigned student toCabot House
# assigned student toLeverett House
# assigned student toEliot House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toQuincy House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toLeverett House
# assigned student toLeverett House
# assigned student toEliot House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toLowell House
# assigned student toDunster House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toCabot House
# assigned student toDunster House
# assigned student toLowell House
# assigned student toMather House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toDunster House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toCurrier House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toDunster House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toDunster House
# assigned student toLeverett House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toMather House
# assigned student toEliot House
# assigned student toPforzheimer House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toQuincy House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toQuincy House
# assigned student toCurrier House
# assigned student toWinthrop House
# assigned student toCurrier House
# assigned student toMather House
# assigned student toDunster House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toDunster House
# assigned student toCurrier House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toLeverett House
# assigned student toCurrier House
# assigned student toEliot House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toAdams House
# assigned student toMather House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toDunster House
# assigned student toCabot House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toQuincy House
# assigned student toEliot House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toWinthrop House
# assigned student toDunster House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toWinthrop House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toAdams House
# assigned student toDunster House
# assigned student toWinthrop House
# assigned student toQuincy House
# assigned student toLeverett House
# assigned student toDunster House
# assigned student toKirkland House
# assigned student toCabot House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toCurrier House
# assigned student toAdams House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toMather House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toCabot House
# assigned student toQuincy House
# ...
# no more capacity in Currier House
# assigned student toLeverett House
# assigned student toLowell House
# no more capacity in Quincy House
# no more capacity in Currier House
# assigned student toPforzheimer House
# assigned student toAdams House
# no more capacity in Dunster House
# assigned student toCabot House
# assigned student toMather House
# no more capacity in Dunster House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toLeverett House
# no more capacity in Dunster House
# assigned student toLowell House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toAdams House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toMather House
# assigned student toEliot House
# assigned student toCabot House
# no more capacity in Quincy House
# assigned student toLowell House
# no more capacity in Currier House
# assigned student toEliot House
# no more capacity in Currier House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toKirkland House
# no more capacity in Dunster House
# no more capacity in Currier House
# assigned student toAdams House
# assigned student toMather House
# assigned student toKirkland House
# no more capacity in Currier House
# assigned student toWinthrop House
# assigned student toWinthrop House
# assigned student toCabot House
# no more capacity in Currier House
# no more capacity in Quincy House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toMather House
# no more capacity in Dunster House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toEliot House
# assigned student toWinthrop House
# assigned student toLowell House
# no more capacity in Currier House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toWinthrop House
# no more capacity in Dunster House
# assigned student toLeverett House
# assigned student toLeverett House
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toLowell House
# no more capacity in Quincy House
# assigned student toEliot House
# assigned student toCabot House
# assigned student toEliot House
# assigned student toMather House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toLeverett House
# assigned student toAdams House
# no more capacity in Dunster House
# no more capacity in Dunster House
# assigned student toEliot House
# assigned student toLowell House
# no more capacity in Quincy House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toKirkland House
# assigned student toAdams House
# no more capacity in Quincy House
# assigned student toEliot House
# assigned student toKirkland House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# assigned student toLowell House
# no more capacity in Dunster House
# no more capacity in Currier House
# assigned student toEliot House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# no more capacity in Quincy House
# assigned student toEliot House
# assigned student toLowell House
# assigned student toEliot House
# assigned student toMather House
# assigned student toMather House
# assigned student toLowell House
# assigned student toKirkland House
# no more capacity in Quincy House
# no more capacity in Currier House
# assigned student toMather House
# no more capacity in Currier House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toLeverett House
# no more capacity in Quincy House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toEliot House
# no more capacity in Quincy House
# no more capacity in Currier House
# no more capacity in Currier House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toCabot House
# assigned student toEliot House
# no more capacity in Quincy House
# assigned student toLeverett House
# no more capacity in Currier House
# assigned student toLowell House
# assigned student toWinthrop House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toAdams House
# assigned student toEliot House
# no more capacity in Dunster House
# assigned student toWinthrop House
# no more capacity in Quincy House
# assigned student toAdams House
# assigned student toAdams House
# no more capacity in Quincy House
# no more capacity in Dunster House
# assigned student toAdams House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toCabot House
# assigned student toAdams House
# assigned student toEliot House
# assigned student toEliot House
# assigned student toMather House
# assigned student toAdams House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toAdams House
# assigned student toPforzheimer House
# assigned student toPforzheimer House
# no more capacity in Dunster House
# no more capacity in Cabot House
# assigned student toWinthrop House
# assigned student toKirkland House
# assigned student toPforzheimer House
# assigned student toKirkland House
# no more capacity in Dunster House
# assigned student toWinthrop House
# assigned student toWinthrop House
# no more capacity in Cabot House
# no more capacity in Quincy House
# assigned student toMather House
# assigned student toLowell House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# no more capacity in Dunster House
# no more capacity in Currier House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toAdams House
# no more capacity in Quincy House
# assigned student toMather House
# assigned student toKirkland House
# no more capacity in Quincy House
# assigned student toKirkland House
# no more capacity in Currier House
# assigned student toWinthrop House
# assigned student toLowell House
# assigned student toPforzheimer House
# assigned student toMather House
# no more capacity in Quincy House
# no more capacity in Cabot House
# assigned student toEliot House
# no more capacity in Currier House
# assigned student toMather House
# assigned student toKirkland House
# assigned student toPforzheimer House
# assigned student toLowell House
# assigned student toMather House
# assigned student toLeverett House
# no more capacity in Dunster House
# no more capacity in Currier House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toLowell House
# no more capacity in Adams House
# no more capacity in Currier House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toWinthrop House
# assigned student toKirkland House
# assigned student toMather House
# assigned student toLowell House
# no more capacity in Adams House
# no more capacity in Quincy House
# assigned student toPforzheimer House
# assigned student toEliot House
# no more capacity in Dunster House
# assigned student toLeverett House
# assigned student toMather House
# no more capacity in Dunster House
# no more capacity in Currier House
# assigned student toPforzheimer House
# no more capacity in Quincy House
# no more capacity in Cabot House
# no more capacity in Quincy House
# no more capacity in Dunster House
# assigned student toPforzheimer House
# assigned student toKirkland House
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toWinthrop House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toEliot House
# assigned student toKirkland House
# no more capacity in Cabot House
# assigned student toLowell House
# no more capacity in Currier House
# assigned student toMather House
# no more capacity in Currier House
# assigned student toLeverett House
# no more capacity in Eliot House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toMather House
# no more capacity in Eliot House
# no more capacity in Cabot House
# no more capacity in Cabot House
# assigned student toLeverett House
# assigned student toPforzheimer House
# assigned student toWinthrop House
# no more capacity in Quincy House
# no more capacity in Adams House
# assigned student toMather House
# no more capacity in Eliot House
# assigned student toKirkland House
# assigned student toKirkland House
# assigned student toKirkland House
# no more capacity in Dunster House
# no more capacity in Currier House
# no more capacity in Eliot House
# no more capacity in Currier House
# no more capacity in Currier House
# no more capacity in Dunster House
# assigned student toLeverett House
# assigned student toMather House
# assigned student toLowell House
# assigned student toLeverett House
# assigned student toLowell House
# assigned student toLowell House
# no more capacity in Eliot House
# assigned student toLeverett House
# assigned student toWinthrop House
# no more capacity in Dunster House
# assigned student toPforzheimer House
# assigned student toLeverett House
# assigned student toWinthrop House
# no more capacity in Eliot House
# no more capacity in Currier House
# assigned student toWinthrop House
# assigned student toWinthrop House
# no more capacity in Eliot House
# no more capacity in Cabot House
# no more capacity in Adams House
# assigned student toWinthrop House
# no more capacity in Currier House
# no more capacity in Adams House
# no more capacity in Quincy House
# assigned student toLeverett House
# no more capacity in Currier House
# no more capacity in Cabot House
# no more capacity in Eliot House
# no more capacity in Eliot House
# no more capacity in Currier House
# no more capacity in Currier House
# no more capacity in Eliot House
# no more capacity in Adams House
# assigned student toWinthrop House
# assigned student toLowell House
# no more capacity in Currier House
# assigned student toLeverett House
# assigned student toWinthrop House
# assigned student toMather House
# no more capacity in Adams House
# no more capacity in Currier House
# no more capacity in Adams House
# assigned student toMather House
# assigned student toMather House
# assigned student toPforzheimer House
# no more capacity in Dunster House
# no more capacity in Dunster House
# assigned student toWinthrop House
# assigned student toMather House
# assigned student toPforzheimer House
# assigned student toMather House
# no more capacity in Adams House
# assigned student toMather House
# assigned student toLeverett House
# no more capacity in Dunster House
# assigned student toPforzheimer House
# no more capacity in Cabot House
# no more capacity in Adams House
# assigned student toWinthrop House
# no more capacity in Eliot House
# assigned student toKirkland House
# assigned student toLowell House
# no more capacity in Currier House
# no more capacity in Eliot House
# no more capacity in Adams House
# no more capacity in Currier House
# no more capacity in Adams House
# assigned student toWinthrop House
# assigned student toKirkland House
# assigned student toWinthrop House
# assigned student toPforzheimer House
# no more capacity in Dunster House
# assigned student toLowell House
# no more capacity in Quincy House
# no more capacity in Dunster House
# assigned student toKirkland House
# no more capacity in Winthrop House
# no more capacity in Winthrop House
# no more capacity in Cabot House
# no more capacity in Winthrop House
# no more capacity in Winthrop House
# no more capacity in Currier House
# no more capacity in Eliot House
# no more capacity in Dunster House
# no more capacity in Cabot House
# no more capacity in Quincy House
# assigned student toLowell House
# assigned student toPforzheimer House
# no more capacity in Quincy House
# no more capacity in Adams House
# no more capacity in Eliot House
# no more capacity in Quincy House
# assigned student toKirkland House
# no more capacity in Quincy House
# no more capacity in Adams House
# no more capacity in Winthrop House
# assigned student toPforzheimer House
# no more capacity in Quincy House
# assigned student toKirkland House
# no more capacity in Winthrop House
# no more capacity in Dunster House
# no more capacity in Eliot House
# no more capacity in Winthrop House
# no more capacity in Eliot House
# assigned student toLowell House
# no more capacity in Quincy House
# assigned student toMather House
# no more capacity in Quincy House
# no more capacity in Eliot House
# no more capacity in Quincy House
# no more capacity in Adams House
# no more capacity in Winthrop House
# no more capacity in Cabot House
# assigned student toKirkland House
# no more capacity in Quincy House
# assigned student toLowell House
# no more capacity in Eliot House
# no more capacity in Dunster House
# assigned student toKirkland House
# assigned student toPforzheimer House
# assigned student toLowell House
# no more capacity in Eliot House
# no more capacity in Eliot House
# no more capacity in Eliot House
# no more capacity in Adams House
# no more capacity in Winthrop House
# no more capacity in Eliot House
# assigned student toMather House
# no more capacity in Winthrop House
# no more capacity in Winthrop House
# assigned student toKirkland House
# no more capacity in Winthrop House
# no more capacity in Dunster House
# assigned student toLeverett House
# no more capacity in Cabot House
# no more capacity in Winthrop House
# no more capacity in Dunster House
# no more capacity in Cabot House
# no more capacity in Pforzheimer House
# assigned student toLeverett House
# no more capacity in Quincy House
# no more capacity in Winthrop House
# no more capacity in Winthrop House
# no more capacity in Dunster House
# no more capacity in Adams House
# no more capacity in Dunster House
# assigned student toLowell House
# assigned student toKirkland House
# no more capacity in Currier House
# no more capacity in Mather House
# no more capacity in Mather House
# no more capacity in Adams House
# no more capacity in Dunster House
# no more capacity in Winthrop House
# no more capacity in Dunster House
# assigned student toLeverett House
# no more capacity in Adams House
# no more capacity in Dunster House
# assigned student toLowell House
# no more capacity in Currier House
# no more capacity in Eliot House
# no more capacity in Pforzheimer House
# no more capacity in Pforzheimer House
# no more capacity in Adams House
# no more capacity in Quincy House
# no more capacity in Eliot House
# assigned student toKirkland House
# assigned student toLowell House
# no more capacity in Currier House
# no more capacity in Winthrop House
# no more capacity in Currier House
# assigned student toLeverett House
# no more capacity in Winthrop House
# no more capacity in Cabot House
# no more capacity in Cabot House
# assigned student toLowell House
# no more capacity in Winthrop House
# no more capacity in Currier House
# assigned student toKirkland House
# no more capacity in Cabot House
# no more capacity in Winthrop House
# no more capacity in Pforzheimer House
# no more capacity in Adams House
# no more capacity in Eliot House
# no more capacity in Cabot House
# assigned student toKirkland House
# no more capacity in Mather House
# no more capacity in Winthrop House
# no more capacity in Dunster House
# no more capacity in Quincy House
# no more capacity in Currier House
# no more capacity in Currier House
# no more capacity in Pforzheimer House
# no more capacity in Currier House
# no more capacity in Cabot House
# no more capacity in Mather House
# no more capacity in Quincy House
# assigned student toKirkland House
# assigned student toLowell House
# no more capacity in Currier House
# no more capacity in Winthrop House
# no more capacity in Dunster House
# no more capacity in Cabot House
# no more capacity in Winthrop House
# no more capacity in Winthrop House
# no more capacity in Currier House
# no more capacity in Currier House
# no more capacity in Winthrop House
# assigned student toLowell House
# no more capacity in Winthrop House
# no more capacity in Eliot House
# no more capacity in Adams House
# no more capacity in Currier House
# no more capacity in Cabot House
# no more capacity in Pforzheimer House
# assigned student toLeverett House
# assigned student toLowell House
# no more capacity in Cabot House
# assigned student toLowell House

# %%
# let's now check whether this worked better using our small function from before
students_per_house_correct = calculate_students_per_house('data/students_with_house_correct_capacity.csv')
students_per_house_correct

house_assignment_check(students_per_house_correct)
# Out:
# no assignment problems with Adams House
# no assignment problems with Cabot House
# no assignment problems with Currier House
# no assignment problems with Dunster House
# no assignment problems with Eliot House
# no assignment problems with Kirkland House
# no assignment problems with Leverett House
# no assignment problems with Lowell House
# no assignment problems with Mather House
# no assignment problems with Pforzheimer House
# no assignment problems with Quincy House
# no assignment problems with Winthrop House

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Full Implementation in Pandas
#
# 1. calculate vacant rooms per house
# 2. write a program that computes the number of students assigned per house in a given csv
# 3. write a function that checks whether there are problems with the numbers of students assigned to each house
# 4. write code that assigns students randomly but in such a way that there are no capacity issues.

# %%
import pandas as pd

# %%
df_students = pd.read_csv('data/students.csv')
df_students.columns = ['first_name','last_name','id','email']
df_students
# Out:
#      first_name last_name        id                                   email
# 0          Hope     Quent  16435294          Hope.Quent@college.harvard.edu
# 1         Fayre   Vorster  11185066       Fayre.Vorster@college.harvard.edu
# 2     Priscilla   Geffner  14666772   Priscilla.Geffner@college.harvard.edu
# 3     Madeleine  Stilwell  13502774  Madeleine.Stilwell@college.harvard.edu
# 4       Deirdre    Khorma  11100518      Deirdre.Khorma@college.harvard.edu
# ...         ...       ...       ...                                     ...
# 1994       Kate    Selway  11613307         Kate.Selway@college.harvard.edu
# 1995  Marsiella    Edmund  17939908    Marsiella.Edmund@college.harvard.edu
# 1996     Gretal    Muriel  17593926       Gretal.Muriel@college.harvard.edu
# 1997      Gilda    Brieta  11581271        Gilda.Brieta@college.harvard.edu
# 1998      Deane     Faria  18144500         Deane.Faria@college.harvard.edu
#
# [1999 rows x 4 columns]

# %%
# TASK #1: add random int between 0-11, which is equal to House_id - then add house name 
# TASK #2: create custom dataframes for each house and save them as csv files for each house 
# BONUS: Calculate vacancies (so that you know: Lev has 103 spots, Mather has 124 spots) and test if current csvs hold up to those numbers or fail! (do that in pandas, too)
# 
# shuffle names and then assign adequate number of students per house

# %%
# solution for
